# %%
import os
import sys

import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
import collections

import networkx as nx
import torch

from basicmemnet import memnet
from basicmemnet import plot_graph

from pykeen.triples import TriplesFactory, TriplesNumericLiteralsFactory, CoreTriplesFactory
from pykeen.pipeline import pipeline
from pykeen.models import Model

# %%
md_test = memnet.DSL()

md_test.import_gml("test_graph.gml")

test = md_test.get_graph()

def get_triplets(G):
    triples = []
    id_to_utterance = {}
    for u, v, data in G.edges(data=True):
        relation = data.get('link_type')
        head = G.nodes[u].get('utterances')[0]
        tail = G.nodes[v].get('utterances')[0]
        # triples.append([u, relation, v])
        triples.append([u, relation, v])
        id_to_utterance[u] = head
        id_to_utterance[v] = tail
    return np.array(triples), id_to_utterance

test_triplets, id_to_utterance = get_triplets(test)
print('Number of test triplets: ',len(test_triplets))
print(test_triplets[:3])
# Out:
# Number of test triplets:  6680
# [['668f64fb8cc61c379809bfe8' 'has_actor' '668f64fb8cc61c379809bfe9']
#  ['668f64fb8cc61c379809bfe8' 'has_element' '668f64fb8cc61c379809bfea']
#  ['668f64fb8cc61c379809bfe8' 'has_element' '668f64fb8cc61c379809bfeb']]

# %% [markdown]
# ### RotatE parentAction

# %%
# model_version = "parentAction_transe_word_350epochs"
model_version = "parentAction_RotatE_word_200epochs"
trained_model_path = f"doctests/{model_version}/trained_model.pkl"
model = torch.load(trained_model_path)

triples_factory = TriplesFactory.from_path_binary(f"doctests/{model_version}/training_triples")
entity_to_id = triples_factory.entity_to_id
entity_id_to_label = triples_factory.entity_id_to_label
relation_to_id = triples_factory.relation_to_id

test_set = np.array([triple for triple in test_triplets if 'has_element' in triple])
mapped_test_data = np.array([[entity_to_id[id_to_utterance[h]], relation_to_id[r], entity_to_id[id_to_utterance[t]]] for h, r, t in test_set])

# %%
true_labels = mapped_test_data[:, 0]
print("true_labels", true_labels)
rel_tail = mapped_test_data[:, 1:]
print("rel_tail", rel_tail)

all_scores = model.predict_h(rt_batch=torch.tensor(rel_tail))
predicted_heads= [scores.argmax().item() for scores in all_scores]

sum(predicted_heads == true_labels)/len(true_labels)*100
# Out:
# true_labels [29 29 29 ... 37 37 37]
# rel_tail [[ 1 12]
#  [ 1  0]
#  [ 1 14]
#  ...
#  [ 1  0]
#  [ 1 11]
#  [ 1 17]]
# 15.335326783425888

# %%
df = []
for index in range (len(test_set)):
    parend_id = test_set[index][0]
    pred = entity_id_to_label[predicted_heads[index]]
    df.append((parend_id, pred))

df1 = pd.DataFrame(df).groupby(0).agg(list).reset_index()
df1.head()

df1[1] = df1[1].apply(lambda x: max(collections.Counter(x), key=collections.Counter(x).get))
df1

df1[0] = df1[0].apply(lambda x: id_to_utterance[x])

sum(df1[0] == df1[1])/len(df1[0])
# Out:
# 0.1111111111111111

# %% [markdown]
# ### RESCAL parent Action

# %%
# model_version = "parentAction_transe_word_350epochs"
model_version = "parentAction_RESCAL_word_350epochs"
trained_model_path = f"doctests/{model_version}/trained_model.pkl"
model = torch.load(trained_model_path)

triples_factory = TriplesFactory.from_path_binary(f"doctests/{model_version}/training_triples")
entity_to_id = triples_factory.entity_to_id
entity_id_to_label = triples_factory.entity_id_to_label
relation_to_id = triples_factory.relation_to_id

# %%
test_set = np.array([triple for triple in test_triplets if 'has_element' in triple])
mapped_test_data = np.array([[entity_to_id[id_to_utterance[h]], relation_to_id[r], entity_to_id[id_to_utterance[t]]] for h, r, t in test_set])

# %%
true_labels = mapped_test_data[:, 0]
print("true_labels", true_labels)
rel_tail = mapped_test_data[:, 1:]
print("rel_tail", rel_tail)
# Out:
# true_labels [29 29 29 ... 37 37 37]
# rel_tail [[ 1 12]
#  [ 1  0]
#  [ 1 14]
#  ...
#  [ 1  0]
#  [ 1 11]
#  [ 1 17]]

# %%
all_scores = model.predict_h(rt_batch=torch.tensor(rel_tail))
predicted_heads= [scores.argmax().item() for scores in all_scores]

sum(predicted_heads == true_labels)/len(true_labels)*100
# Out:
# 12.259718069201195

# %%
df = []
for index in range (len(test_set)):
    parend_id = test_set[index][0]
    pred = entity_id_to_label[predicted_heads[index]]
    df.append((parend_id, pred))
df
# Out:
# [('668f64fb8cc61c379809bfe8', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfe8', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfe8', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfe8', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfe8', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfe8', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfe8', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfe8', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfe8', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfe8', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfe8', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfe8', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfe8', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfe8', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfe8', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfe8', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfe8', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfe8', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfff', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfff', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfff', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfff', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfff', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfff', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfff', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfff', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfff', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfff', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfff', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfff', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfff', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfff', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfff', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfff', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfff', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809bfff', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0c7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0c7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0c7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0c7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0c7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0c7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0c7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0c7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0c7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0c7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0c7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0c7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0c7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0c7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0c7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0c7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0c7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0c7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0dd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0dd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0dd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0dd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0dd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0dd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0dd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0dd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0dd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0dd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0dd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0dd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0dd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0dd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0dd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0dd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0dd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c0dd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c182', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c182', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c182', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c182', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c182', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c182', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c182', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c182', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c182', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c182', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c182', 'task_3_k_pouring'),
#  ('668f64fb8cc61c379809c182', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c182', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c193', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c193', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c193', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c193', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c193', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c193', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c193', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c193', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c193', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c193', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c193', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c193', 'task_3_k_pouring'),
#  ('668f64fb8cc61c379809c193', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c193', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c249', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c249', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c249', 'task_3_k_pouring'),
#  ('668f64fb8cc61c379809c249', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c249', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c249', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c249', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c249', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c249', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c249', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c249', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c249', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c249', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c249', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c249', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c25d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c25d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c25d', 'task_3_k_pouring'),
#  ('668f64fb8cc61c379809c25d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c25d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c25d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c25d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c25d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c25d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c25d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c25d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c25d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c25d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c25d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c25d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_1_k_cooking'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3aa', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_1_k_cooking'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c3d4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_6_w_hard_drive'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_6_w_hard_drive'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c505', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_6_w_hard_drive'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_6_w_hard_drive'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c528', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c645', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c645', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c645', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c645', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c645', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c645', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c645', 'task_6_w_hard_drive'),
#  ('668f64fb8cc61c379809c645', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c645', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c645', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c645', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c645', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c645', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c645', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c645', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c645', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c645', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c645', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c645', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c645', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_6_w_hard_drive'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_6_w_hard_drive'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_6_w_hard_drive'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_6_w_hard_drive'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_6_w_hard_drive'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_6_w_hard_drive'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c65d', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_8_w_hammering'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_8_w_hammering'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c73b', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_8_w_hammering'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_8_w_hammering'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_8_w_hammering'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c75c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c7f3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c7f3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c7f3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c7f3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c7f3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c7f3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c7f3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c7f3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c7f3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c7f3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c7f3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c7f3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c7f3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c804', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c804', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c804', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c804', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c804', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c804', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c804', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c804', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c804', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c804', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c804', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c804', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c804', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c804', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c804', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c804', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8d0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8d0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8d0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8d0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8d0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8d0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8d0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8d0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8d0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8d0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8d0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8d0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8d0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8d0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8d0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8d0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8d0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8d0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8e7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8e7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8e7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8e7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8e7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8e7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8e7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8e7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8e7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8e7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8e7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8e7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8e7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8e7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8e7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8e7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8e7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c8e7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9b6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9b6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9b6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9b6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9b6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9b6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9b6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9b6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9b6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9b6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9b6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9b6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9b6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9b6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9b6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9b6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9b6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9b6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9cd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9cd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9cd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9cd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9cd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9cd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9cd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9cd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9cd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9cd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9cd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9cd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9cd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9cd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9cd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9cd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9cd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809c9cd', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca74', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca74', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca74', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca74', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca74', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca74', 'task_3_k_pouring'),
#  ('668f64fb8cc61c379809ca74', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca74', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca74', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca74', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca74', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca74', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca74', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca74', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca86', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca86', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca86', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca86', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca86', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca86', 'task_3_k_pouring'),
#  ('668f64fb8cc61c379809ca86', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca86', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca86', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca86', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca86', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca86', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca86', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ca86', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cb43', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cb43', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cb43', 'task_3_k_pouring'),
#  ('668f64fb8cc61c379809cb43', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cb4a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cb4a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cb4a', 'task_3_k_pouring'),
#  ('668f64fb8cc61c379809cb4a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cb4a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cb4a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cb4a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cb4a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cb4a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cb4a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cb4a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cb4a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cb4a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cb4a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cb4a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_1_k_cooking'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cc99', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_1_k_cooking'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ccc4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_6_w_hard_drive'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_6_w_hard_drive'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdd7', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_6_w_hard_drive'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_6_w_hard_drive'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cdf3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ceb3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ceb3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ceb3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ceb3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ceb3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ceb3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ceb3', 'task_6_w_hard_drive'),
#  ('668f64fb8cc61c379809ceb3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ceb3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ceb3', 'task_6_w_hard_drive'),
#  ('668f64fb8cc61c379809ceb3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ceb3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ceb3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ceb3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ceb3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ceb3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ceb3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809ceb3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cec9', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cec9', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cec9', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cec9', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cec9', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cec9', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cec9', 'task_6_w_hard_drive'),
#  ('668f64fb8cc61c379809cec9', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cec9', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cec9', 'task_6_w_hard_drive'),
#  ('668f64fb8cc61c379809cec9', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cec9', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cec9', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cec9', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cec9', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cec9', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cec9', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cec9', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_8_w_hammering'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_8_w_hammering'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cfd6', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_8_w_hammering'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_8_w_hammering'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809cff5', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d09f', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d09f', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d09f', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d09f', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d09f', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d09f', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d09f', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d09f', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d09f', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d09f', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d09f', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d09f', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d09f', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d09f', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d09f', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d09f', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d09f', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d0b4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d0b4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d0b4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d0b4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d0b4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d0b4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d0b4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d0b4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d0b4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d0b4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d0b4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d0b4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d0b4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d0b4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d0b4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d0b4', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d180', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d180', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d180', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d180', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d180', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d180', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d180', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d180', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d180', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d180', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d180', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d180', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d180', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d180', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d180', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d180', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d180', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d180', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d197', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d197', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d197', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d197', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d197', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d197', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d197', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d197', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d197', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d197', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d197', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d197', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d197', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d197', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d197', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d197', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d197', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d197', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d25e', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d25e', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d25e', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d25e', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d25e', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d25e', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d25e', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d25e', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d25e', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d25e', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d25e', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d25e', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d25e', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d25e', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d25e', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d25e', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d25e', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d25e', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d274', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d318', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d318', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d318', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d318', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d318', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d318', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d318', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d318', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d318', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d318', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d318', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d318', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d318', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d318', 'task_3_k_pouring'),
#  ('668f64fb8cc61c379809d318', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d318', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d32c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d32c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d32c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d32c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d32c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d32c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d32c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d32c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d32c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d32c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d32c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d32c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d32c', 'task_3_k_pouring'),
#  ('668f64fb8cc61c379809d32c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d32c', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d407', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d407', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d407', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d407', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d407', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d407', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d407', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d407', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d407', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d407', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d407', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d407', 'task_3_k_pouring'),
#  ('668f64fb8cc61c379809d407', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d419', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d419', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d419', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d419', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d419', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d419', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d419', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d419', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d419', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d419', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d419', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d419', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d419', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d419', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d419', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d419', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d419', 'task_3_k_pouring'),
#  ('668f64fb8cc61c379809d419', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_1_k_cooking'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d57a', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_1_k_cooking'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fb8cc61c379809d5a3', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_6_w_hard_drive'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_6_w_hard_drive'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_6_w_hard_drive'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_6_w_hard_drive'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d6e0', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d702', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d702', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d702', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d702', 'task_2_k_cooking_with_bowls'),
#  ('668f64fc8cc61c379809d702', 'task_2_k_cooking_with_bowls'),
#  ...]

# %%
df1 = pd.DataFrame(df).groupby(0).agg(list).reset_index()
df1.head()
# Out:
#                           0                                                  1
# 0  668f64fb8cc61c379809bfe8  [task_2_k_cooking_with_bowls, task_2_k_cooking...
# 1  668f64fb8cc61c379809bfff  [task_2_k_cooking_with_bowls, task_2_k_cooking...
# 2  668f64fb8cc61c379809c0c7  [task_2_k_cooking_with_bowls, task_2_k_cooking...
# 3  668f64fb8cc61c379809c0dd  [task_2_k_cooking_with_bowls, task_2_k_cooking...
# 4  668f64fb8cc61c379809c182  [task_2_k_cooking_with_bowls, task_2_k_cooking...

# %%
df1[1] = df1[1].apply(lambda x: max(collections.Counter(x), key=collections.Counter(x).get))
df1
# Out:
#                             0                            1
# 0    668f64fb8cc61c379809bfe8  task_2_k_cooking_with_bowls
# 1    668f64fb8cc61c379809bfff  task_2_k_cooking_with_bowls
# 2    668f64fb8cc61c379809c0c7  task_2_k_cooking_with_bowls
# 3    668f64fb8cc61c379809c0dd  task_2_k_cooking_with_bowls
# 4    668f64fb8cc61c379809c182  task_2_k_cooking_with_bowls
# ..                        ...                          ...
# 103  668f64fc8cc61c379809f366  task_2_k_cooking_with_bowls
# 104  668f64fc8cc61c379809f4ae  task_2_k_cooking_with_bowls
# 105  668f64fc8cc61c379809f4d3  task_2_k_cooking_with_bowls
# 106  668f64fc8cc61c379809f574  task_2_k_cooking_with_bowls
# 107  668f64fc8cc61c379809f585  task_2_k_cooking_with_bowls
#
# [108 rows x 2 columns]

# %%
df1[0] = df1[0].apply(lambda x: id_to_utterance[x])

sum(df1[0] == df1[1])/len(df1[0])
# Out:
# 0.1111111111111111

# %%
df1
# Out:
#                                0                            1
# 0               task_1_k_cooking  task_2_k_cooking_with_bowls
# 1               task_1_k_cooking  task_2_k_cooking_with_bowls
# 2    task_2_k_cooking_with_bowls  task_2_k_cooking_with_bowls
# 3    task_2_k_cooking_with_bowls  task_2_k_cooking_with_bowls
# 4               task_3_k_pouring  task_2_k_cooking_with_bowls
# ..                           ...                          ...
# 103     task_7_w_free_hard_drive  task_2_k_cooking_with_bowls
# 104           task_8_w_hammering  task_2_k_cooking_with_bowls
# 105           task_8_w_hammering  task_2_k_cooking_with_bowls
# 106              task_9_w_sawing  task_2_k_cooking_with_bowls
# 107              task_9_w_sawing  task_2_k_cooking_with_bowls
#
# [108 rows x 2 columns]

# %%
preds = []
trues = []
for i, (pred, true) in enumerate(zip(predicted_heads, true_labels)):
    predicted_head_str = entity_id_to_label[pred]
    preds.append(predicted_head_str)
    true_head_str = entity_id_to_label[true]
    trues.append(true_head_str)
    print(f"Prediction {i+1}: Predicted head = {predicted_head_str}, True head = {true_head_str}")
# Out:
# Prediction 1: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 2: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 3: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 4: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 5: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 6: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 7: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 8: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 9: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 10: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 11: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 12: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 13: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 14: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 15: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 16: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 17: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 18: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 19: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 20: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 21: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 22: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 23: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 24: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 25: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 26: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 27: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 28: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 29: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 30: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 31: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 32: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 33: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 34: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 35: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 36: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 37: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 38: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 39: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 40: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 41: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 42: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 43: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 44: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 45: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 46: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 47: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 48: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 49: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 50: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 51: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 52: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 53: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 54: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 55: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 56: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 57: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 58: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 59: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 60: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 61: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 62: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 63: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 64: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 65: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 66: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 67: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 68: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 69: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 70: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 71: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 72: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 73: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 74: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 75: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 76: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 77: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 78: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 79: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 80: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 81: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 82: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 83: Predicted head = task_3_k_pouring, True head = task_3_k_pouring
# Prediction 84: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 85: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 86: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 87: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 88: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 89: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 90: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 91: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 92: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 93: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 94: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 95: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 96: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 97: Predicted head = task_3_k_pouring, True head = task_3_k_pouring
# Prediction 98: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 99: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 100: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 101: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 102: Predicted head = task_3_k_pouring, True head = task_4_k_wiping
# Prediction 103: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 104: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 105: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 106: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 107: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 108: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 109: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 110: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 111: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 112: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 113: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 114: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 115: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 116: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 117: Predicted head = task_3_k_pouring, True head = task_4_k_wiping
# Prediction 118: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 119: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 120: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 121: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 122: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 123: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 124: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 125: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 126: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 127: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 128: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 129: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 130: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 131: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 132: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 133: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 134: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 135: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 136: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 137: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 138: Predicted head = task_1_k_cooking, True head = task_5_k_cereals
# Prediction 139: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 140: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 141: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 142: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 143: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 144: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 145: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 146: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 147: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 148: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 149: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 150: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 151: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 152: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 153: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 154: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 155: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 156: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 157: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 158: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 159: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 160: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 161: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 162: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 163: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 164: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 165: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 166: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 167: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 168: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 169: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 170: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 171: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 172: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 173: Predicted head = task_1_k_cooking, True head = task_5_k_cereals
# Prediction 174: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 175: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 176: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 177: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 178: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 179: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 180: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 181: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 182: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 183: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 184: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 185: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 186: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 187: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 188: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 189: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 190: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 191: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 192: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 193: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 194: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 195: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 196: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 197: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 198: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 199: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 200: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 201: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 202: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 203: Predicted head = task_6_w_hard_drive, True head = task_6_w_hard_drive
# Prediction 204: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 205: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 206: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 207: Predicted head = task_6_w_hard_drive, True head = task_6_w_hard_drive
# Prediction 208: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 209: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 210: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 211: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 212: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 213: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 214: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 215: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 216: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 217: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 218: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 219: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 220: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 221: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 222: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 223: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 224: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 225: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 226: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 227: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 228: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 229: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 230: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 231: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 232: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 233: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 234: Predicted head = task_6_w_hard_drive, True head = task_6_w_hard_drive
# Prediction 235: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 236: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 237: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 238: Predicted head = task_6_w_hard_drive, True head = task_6_w_hard_drive
# Prediction 239: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 240: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 241: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 242: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 243: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 244: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 245: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 246: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 247: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 248: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 249: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 250: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 251: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 252: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 253: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 254: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 255: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 256: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 257: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 258: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 259: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 260: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 261: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 262: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 263: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 264: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 265: Predicted head = task_6_w_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 266: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 267: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 268: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 269: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 270: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 271: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 272: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 273: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 274: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 275: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 276: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 277: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 278: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 279: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 280: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 281: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 282: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 283: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 284: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 285: Predicted head = task_6_w_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 286: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 287: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 288: Predicted head = task_6_w_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 289: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 290: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 291: Predicted head = task_6_w_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 292: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 293: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 294: Predicted head = task_6_w_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 295: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 296: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 297: Predicted head = task_6_w_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 298: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 299: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 300: Predicted head = task_6_w_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 301: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 302: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 303: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 304: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 305: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 306: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 307: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 308: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 309: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 310: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 311: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 312: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 313: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 314: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 315: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 316: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 317: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 318: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 319: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 320: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 321: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 322: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 323: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 324: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 325: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 326: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 327: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 328: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 329: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 330: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 331: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 332: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 333: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 334: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 335: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 336: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 337: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 338: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 339: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 340: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 341: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 342: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 343: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 344: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 345: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 346: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 347: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 348: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 349: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 350: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 351: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 352: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 353: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 354: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 355: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 356: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 357: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 358: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 359: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 360: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 361: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 362: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 363: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 364: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 365: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 366: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 367: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 368: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 369: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 370: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 371: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 372: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 373: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 374: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 375: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 376: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 377: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 378: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 379: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 380: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 381: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 382: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 383: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 384: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 385: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 386: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 387: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 388: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 389: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 390: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 391: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 392: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 393: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 394: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 395: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 396: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 397: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 398: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 399: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 400: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 401: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 402: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 403: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 404: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 405: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 406: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 407: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 408: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 409: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 410: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 411: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 412: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 413: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 414: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 415: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 416: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 417: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 418: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 419: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 420: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 421: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 422: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 423: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 424: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 425: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 426: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 427: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 428: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 429: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 430: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 431: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 432: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 433: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 434: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 435: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 436: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 437: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 438: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 439: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 440: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 441: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 442: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 443: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 444: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 445: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 446: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 447: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 448: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 449: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 450: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 451: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 452: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 453: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 454: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 455: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 456: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 457: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 458: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 459: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 460: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 461: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 462: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 463: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 464: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 465: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 466: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 467: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 468: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 469: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 470: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 471: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 472: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 473: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 474: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 475: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 476: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 477: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 478: Predicted head = task_3_k_pouring, True head = task_3_k_pouring
# Prediction 479: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 480: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 481: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 482: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 483: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 484: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 485: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 486: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 487: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 488: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 489: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 490: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 491: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 492: Predicted head = task_3_k_pouring, True head = task_3_k_pouring
# Prediction 493: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 494: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 495: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 496: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 497: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 498: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 499: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 500: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 501: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 502: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 503: Predicted head = task_3_k_pouring, True head = task_4_k_wiping
# Prediction 504: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 505: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 506: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 507: Predicted head = task_3_k_pouring, True head = task_4_k_wiping
# Prediction 508: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 509: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 510: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 511: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 512: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 513: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 514: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# Prediction 515: Predicted head = task_2_k_cooking_with_bowls, True head = task_4_k_wiping
# ...
# Prediction 2175: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2176: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2177: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2178: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2179: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2180: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2181: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2182: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2183: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2184: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2185: Predicted head = task_6_w_hard_drive, True head = task_6_w_hard_drive
# Prediction 2186: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2187: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2188: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2189: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2190: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2191: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2192: Predicted head = task_6_w_hard_drive, True head = task_6_w_hard_drive
# Prediction 2193: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2194: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2195: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2196: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2197: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2198: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2199: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2200: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2201: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2202: Predicted head = task_2_k_cooking_with_bowls, True head = task_6_w_hard_drive
# Prediction 2203: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2204: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2205: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2206: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2207: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2208: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2209: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2210: Predicted head = task_6_w_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 2211: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2212: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2213: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2214: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2215: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2216: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2217: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2218: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2219: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2220: Predicted head = task_6_w_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 2221: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2222: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2223: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2224: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2225: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2226: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2227: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2228: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2229: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2230: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2231: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2232: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2233: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2234: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2235: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2236: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2237: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2238: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2239: Predicted head = task_6_w_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 2240: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2241: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2242: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2243: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2244: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2245: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2246: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2247: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2248: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2249: Predicted head = task_6_w_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 2250: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2251: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2252: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2253: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2254: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2255: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2256: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2257: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2258: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2259: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2260: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2261: Predicted head = task_2_k_cooking_with_bowls, True head = task_7_w_free_hard_drive
# Prediction 2262: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2263: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2264: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2265: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2266: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2267: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2268: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 2269: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2270: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2271: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2272: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 2273: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2274: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2275: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2276: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2277: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2278: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2279: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2280: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2281: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2282: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2283: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2284: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2285: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2286: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2287: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2288: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2289: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2290: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2291: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2292: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2293: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2294: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2295: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2296: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2297: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2298: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 2299: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2300: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2301: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2302: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 2303: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2304: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2305: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2306: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2307: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2308: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2309: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2310: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2311: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2312: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2313: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2314: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2315: Predicted head = task_2_k_cooking_with_bowls, True head = task_8_w_hammering
# Prediction 2316: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2317: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2318: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2319: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2320: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2321: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2322: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2323: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2324: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2325: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2326: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2327: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2328: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2329: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2330: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2331: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2332: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2333: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2334: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2335: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2336: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2337: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2338: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2339: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2340: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing
# Prediction 2341: Predicted head = task_2_k_cooking_with_bowls, True head = task_9_w_sawing

# %% [markdown]
# ### TRANSE next action

# %%
# model_version = "parentAction_transe_word_350epochs"
model_version = "nextAction_RotatE_word_350epochs"
trained_model_path = f"doctests/{model_version}/trained_model.pkl"
model = torch.load(trained_model_path)

triples_factory = TriplesFactory.from_path_binary(f"doctests/{model_version}/training_triples")
entity_to_id = triples_factory.entity_to_id
entity_id_to_label = triples_factory.entity_id_to_label
relation_to_id = triples_factory.relation_to_id

# %%
test_set = np.array([triple for triple in test_triplets if 'has_next' in triple])
mapped_test_data = np.array([[entity_to_id[id_to_utterance[h]], relation_to_id[r], entity_to_id[id_to_utterance[t]]] for h, r, t in test_set])

# %%
# tetest_set = np.array([triple for triple in test_triplets if 'has_element' in triple])
# mapped_test_data = np.array([[entity_to_id[h], relation_to_id[r], entity_to_id[t]] for h, r, t in tetest_set])

# %%
len(test_set)
# Out:
# 2126

# %%
true_labels = mapped_test_data[:, 2] #next action prediction
print("true_labels", true_labels)
head_rel = mapped_test_data[:, :2]
print("head_rel", head_rel)

all_scores = model.predict_t(hr_batch=torch.tensor(head_rel))
predicted_tails= [scores.argmax().item() for scores in all_scores]

print(accuracy_score(true_labels, np.array(predicted_tails)))
# Out:
# true_labels [ 0 14 22 ...  0 11 17]
# head_rel [[12  2]
#  [ 0  2]
#  [14  2]
#  ...
#  [12  2]
#  [ 0  2]
#  [11  2]]
# 0.33113828786453436

# %%
preds = []
trues = []
for i, (pred, true) in enumerate(zip(predicted_tails, true_labels)):
    predicted_head_str = entity_id_to_label[pred]
    preds.append(predicted_head_str)
    true_head_str = entity_id_to_label[true]
    trues.append(true_head_str)
    print(f"Prediction {i+1}: Predicted next action = {predicted_head_str}, True = {true_head_str}")
# Out:
# Prediction 1: Predicted next action = approach, True = approach
# Prediction 2: Predicted next action = retreat, True = lift
# Prediction 3: Predicted next action = retreat, True = stir
# Prediction 4: Predicted next action = place, True = place
# Prediction 5: Predicted next action = retreat, True = retreat
# Prediction 6: Predicted next action = approach, True = approach
# Prediction 7: Predicted next action = retreat, True = hold
# Prediction 8: Predicted next action = place, True = retreat
# Prediction 9: Predicted next action = retreat, True = approach
# Prediction 10: Predicted next action = retreat, True = lift
# Prediction 11: Predicted next action = retreat, True = pour
# Prediction 12: Predicted next action = place, True = place
# Prediction 13: Predicted next action = retreat, True = retreat
# Prediction 14: Predicted next action = retreat, True = approach
# Prediction 15: Predicted next action = retreat, True = hold
# Prediction 16: Predicted next action = place, True = retreat
# Prediction 17: Predicted next action = approach, True = approach
# Prediction 18: Predicted next action = retreat, True = lift
# Prediction 19: Predicted next action = retreat, True = stir
# Prediction 20: Predicted next action = place, True = place
# Prediction 21: Predicted next action = retreat, True = retreat
# Prediction 22: Predicted next action = approach, True = approach
# Prediction 23: Predicted next action = retreat, True = hold
# Prediction 24: Predicted next action = place, True = retreat
# Prediction 25: Predicted next action = retreat, True = approach
# Prediction 26: Predicted next action = retreat, True = lift
# Prediction 27: Predicted next action = retreat, True = pour
# Prediction 28: Predicted next action = place, True = place
# Prediction 29: Predicted next action = retreat, True = retreat
# Prediction 30: Predicted next action = retreat, True = approach
# Prediction 31: Predicted next action = retreat, True = hold
# Prediction 32: Predicted next action = place, True = retreat
# Prediction 33: Predicted next action = approach, True = approach
# Prediction 34: Predicted next action = retreat, True = lift
# Prediction 35: Predicted next action = retreat, True = stir
# Prediction 36: Predicted next action = place, True = place
# Prediction 37: Predicted next action = retreat, True = retreat
# Prediction 38: Predicted next action = approach, True = approach
# Prediction 39: Predicted next action = retreat, True = hold
# Prediction 40: Predicted next action = place, True = retreat
# Prediction 41: Predicted next action = retreat, True = approach
# Prediction 42: Predicted next action = retreat, True = lift
# Prediction 43: Predicted next action = retreat, True = pour
# Prediction 44: Predicted next action = place, True = place
# Prediction 45: Predicted next action = retreat, True = retreat
# Prediction 46: Predicted next action = retreat, True = approach
# Prediction 47: Predicted next action = retreat, True = hold
# Prediction 48: Predicted next action = place, True = retreat
# Prediction 49: Predicted next action = approach, True = approach
# Prediction 50: Predicted next action = retreat, True = lift
# Prediction 51: Predicted next action = retreat, True = stir
# Prediction 52: Predicted next action = place, True = place
# Prediction 53: Predicted next action = retreat, True = retreat
# Prediction 54: Predicted next action = approach, True = approach
# Prediction 55: Predicted next action = retreat, True = hold
# Prediction 56: Predicted next action = place, True = retreat
# Prediction 57: Predicted next action = retreat, True = approach
# Prediction 58: Predicted next action = retreat, True = lift
# Prediction 59: Predicted next action = retreat, True = pour
# Prediction 60: Predicted next action = place, True = place
# Prediction 61: Predicted next action = retreat, True = retreat
# Prediction 62: Predicted next action = retreat, True = approach
# Prediction 63: Predicted next action = retreat, True = hold
# Prediction 64: Predicted next action = place, True = retreat
# Prediction 65: Predicted next action = approach, True = approach
# Prediction 66: Predicted next action = retreat, True = lift
# Prediction 67: Predicted next action = retreat, True = pour
# Prediction 68: Predicted next action = place, True = place
# Prediction 69: Predicted next action = retreat, True = retreat
# Prediction 70: Predicted next action = approach, True = approach
# Prediction 71: Predicted next action = retreat, True = hold
# Prediction 72: Predicted next action = place, True = lift
# Prediction 73: Predicted next action = retreat, True = drink
# Prediction 74: Predicted next action = place, True = place
# Prediction 75: Predicted next action = retreat, True = retreat
# Prediction 76: Predicted next action = approach, True = approach
# Prediction 77: Predicted next action = retreat, True = lift
# Prediction 78: Predicted next action = retreat, True = pour
# Prediction 79: Predicted next action = place, True = place
# Prediction 80: Predicted next action = retreat, True = retreat
# Prediction 81: Predicted next action = approach, True = approach
# Prediction 82: Predicted next action = retreat, True = lift
# Prediction 83: Predicted next action = retreat, True = hold
# Prediction 84: Predicted next action = place, True = lift
# Prediction 85: Predicted next action = retreat, True = drink
# Prediction 86: Predicted next action = place, True = place
# Prediction 87: Predicted next action = retreat, True = retreat
# Prediction 88: Predicted next action = approach, True = approach
# Prediction 89: Predicted next action = retreat, True = wipe
# Prediction 90: Predicted next action = retreat, True = retreat
# Prediction 91: Predicted next action = approach, True = approach
# Prediction 92: Predicted next action = retreat, True = lift
# Prediction 93: Predicted next action = retreat, True = hold
# Prediction 94: Predicted next action = place, True = place
# Prediction 95: Predicted next action = retreat, True = retreat
# Prediction 96: Predicted next action = retreat, True = approach
# Prediction 97: Predicted next action = retreat, True = lift
# Prediction 98: Predicted next action = retreat, True = hold
# Prediction 99: Predicted next action = place, True = place
# Prediction 100: Predicted next action = retreat, True = retreat
# Prediction 101: Predicted next action = approach, True = approach
# Prediction 102: Predicted next action = retreat, True = wipe
# Prediction 103: Predicted next action = retreat, True = retreat
# Prediction 104: Predicted next action = approach, True = approach
# Prediction 105: Predicted next action = retreat, True = lift
# Prediction 106: Predicted next action = retreat, True = hold
# Prediction 107: Predicted next action = place, True = place
# Prediction 108: Predicted next action = retreat, True = retreat
# Prediction 109: Predicted next action = retreat, True = approach
# Prediction 110: Predicted next action = retreat, True = lift
# Prediction 111: Predicted next action = retreat, True = hold
# Prediction 112: Predicted next action = place, True = place
# Prediction 113: Predicted next action = retreat, True = retreat
# Prediction 114: Predicted next action = approach, True = approach
# Prediction 115: Predicted next action = retreat, True = lift
# Prediction 116: Predicted next action = retreat, True = pour
# Prediction 117: Predicted next action = place, True = place
# Prediction 118: Predicted next action = retreat, True = retreat
# Prediction 119: Predicted next action = retreat, True = approach
# Prediction 120: Predicted next action = retreat, True = lift
# Prediction 121: Predicted next action = retreat, True = cut
# Prediction 122: Predicted next action = place, True = retreat
# Prediction 123: Predicted next action = retreat, True = approach
# Prediction 124: Predicted next action = retreat, True = lift
# Prediction 125: Predicted next action = retreat, True = pour
# Prediction 126: Predicted next action = place, True = place
# Prediction 127: Predicted next action = retreat, True = retreat
# Prediction 128: Predicted next action = retreat, True = approach
# Prediction 129: Predicted next action = retreat, True = lift
# Prediction 130: Predicted next action = retreat, True = pour
# Prediction 131: Predicted next action = place, True = place
# Prediction 132: Predicted next action = retreat, True = retreat
# Prediction 133: Predicted next action = approach, True = approach
# Prediction 134: Predicted next action = retreat, True = hold
# Prediction 135: Predicted next action = place, True = retreat
# Prediction 136: Predicted next action = retreat, True = approach
# Prediction 137: Predicted next action = retreat, True = hold
# Prediction 138: Predicted next action = place, True = retreat
# Prediction 139: Predicted next action = retreat, True = approach
# Prediction 140: Predicted next action = retreat, True = lift
# Prediction 141: Predicted next action = retreat, True = hold
# Prediction 142: Predicted next action = place, True = place
# Prediction 143: Predicted next action = retreat, True = retreat
# Prediction 144: Predicted next action = retreat, True = approach
# Prediction 145: Predicted next action = retreat, True = hold
# Prediction 146: Predicted next action = place, True = retreat
# Prediction 147: Predicted next action = approach, True = approach
# Prediction 148: Predicted next action = retreat, True = lift
# Prediction 149: Predicted next action = retreat, True = pour
# Prediction 150: Predicted next action = place, True = place
# Prediction 151: Predicted next action = retreat, True = retreat
# Prediction 152: Predicted next action = retreat, True = approach
# Prediction 153: Predicted next action = retreat, True = lift
# Prediction 154: Predicted next action = retreat, True = cut
# Prediction 155: Predicted next action = place, True = retreat
# Prediction 156: Predicted next action = retreat, True = retreat
# Prediction 157: Predicted next action = retreat, True = lift
# Prediction 158: Predicted next action = retreat, True = pour
# Prediction 159: Predicted next action = place, True = place
# Prediction 160: Predicted next action = retreat, True = retreat
# Prediction 161: Predicted next action = retreat, True = approach
# Prediction 162: Predicted next action = retreat, True = lift
# Prediction 163: Predicted next action = retreat, True = pour
# Prediction 164: Predicted next action = place, True = place
# Prediction 165: Predicted next action = retreat, True = retreat
# Prediction 166: Predicted next action = approach, True = approach
# Prediction 167: Predicted next action = retreat, True = hold
# Prediction 168: Predicted next action = place, True = retreat
# Prediction 169: Predicted next action = retreat, True = approach
# Prediction 170: Predicted next action = retreat, True = hold
# Prediction 171: Predicted next action = place, True = retreat
# Prediction 172: Predicted next action = retreat, True = approach
# Prediction 173: Predicted next action = retreat, True = lift
# Prediction 174: Predicted next action = retreat, True = hold
# Prediction 175: Predicted next action = place, True = place
# Prediction 176: Predicted next action = retreat, True = retreat
# Prediction 177: Predicted next action = retreat, True = approach
# Prediction 178: Predicted next action = retreat, True = hold
# Prediction 179: Predicted next action = place, True = retreat
# Prediction 180: Predicted next action = approach, True = approach
# Prediction 181: Predicted next action = retreat, True = lift
# Prediction 182: Predicted next action = retreat, True = screw
# Prediction 183: Predicted next action = approach, True = retreat
# Prediction 184: Predicted next action = retreat, True = idle
# Prediction 185: Predicted next action = approach, True = approach
# Prediction 186: Predicted next action = retreat, True = screw
# Prediction 187: Predicted next action = approach, True = place
# Prediction 188: Predicted next action = retreat, True = retreat
# Prediction 189: Predicted next action = approach, True = approach
# Prediction 190: Predicted next action = retreat, True = hold
# Prediction 191: Predicted next action = place, True = retreat
# Prediction 192: Predicted next action = retreat, True = approach
# Prediction 193: Predicted next action = retreat, True = hold
# Prediction 194: Predicted next action = place, True = retreat
# Prediction 195: Predicted next action = retreat, True = approach
# Prediction 196: Predicted next action = retreat, True = lift
# Prediction 197: Predicted next action = retreat, True = place
# Prediction 198: Predicted next action = retreat, True = retreat
# Prediction 199: Predicted next action = retreat, True = approach
# Prediction 200: Predicted next action = retreat, True = hold
# Prediction 201: Predicted next action = place, True = retreat
# Prediction 202: Predicted next action = retreat, True = approach
# Prediction 203: Predicted next action = retreat, True = lift
# Prediction 204: Predicted next action = retreat, True = place
# Prediction 205: Predicted next action = retreat, True = retreat
# Prediction 206: Predicted next action = retreat, True = approach
# Prediction 207: Predicted next action = retreat, True = hold
# Prediction 208: Predicted next action = place, True = retreat
# Prediction 209: Predicted next action = approach, True = approach
# Prediction 210: Predicted next action = retreat, True = lift
# Prediction 211: Predicted next action = retreat, True = screw
# Prediction 212: Predicted next action = approach, True = retreat
# Prediction 213: Predicted next action = retreat, True = idle
# Prediction 214: Predicted next action = approach, True = approach
# Prediction 215: Predicted next action = retreat, True = screw
# Prediction 216: Predicted next action = approach, True = place
# Prediction 217: Predicted next action = retreat, True = retreat
# Prediction 218: Predicted next action = approach, True = approach
# Prediction 219: Predicted next action = retreat, True = hold
# Prediction 220: Predicted next action = place, True = retreat
# Prediction 221: Predicted next action = retreat, True = approach
# Prediction 222: Predicted next action = retreat, True = hold
# Prediction 223: Predicted next action = place, True = retreat
# Prediction 224: Predicted next action = retreat, True = approach
# Prediction 225: Predicted next action = retreat, True = lift
# Prediction 226: Predicted next action = retreat, True = place
# Prediction 227: Predicted next action = retreat, True = retreat
# Prediction 228: Predicted next action = retreat, True = approach
# Prediction 229: Predicted next action = retreat, True = hold
# Prediction 230: Predicted next action = place, True = retreat
# Prediction 231: Predicted next action = retreat, True = approach
# Prediction 232: Predicted next action = retreat, True = lift
# Prediction 233: Predicted next action = retreat, True = place
# Prediction 234: Predicted next action = retreat, True = retreat
# Prediction 235: Predicted next action = approach, True = approach
# Prediction 236: Predicted next action = retreat, True = lift
# Prediction 237: Predicted next action = retreat, True = retreat
# Prediction 238: Predicted next action = retreat, True = approach
# Prediction 239: Predicted next action = retreat, True = lift
# Prediction 240: Predicted next action = retreat, True = screw
# Prediction 241: Predicted next action = approach, True = retreat
# Prediction 242: Predicted next action = retreat, True = approach
# Prediction 243: Predicted next action = retreat, True = lift
# Prediction 244: Predicted next action = retreat, True = place
# Prediction 245: Predicted next action = retreat, True = place
# Prediction 246: Predicted next action = retreat, True = retreat
# Prediction 247: Predicted next action = retreat, True = approach
# Prediction 248: Predicted next action = retreat, True = place
# Prediction 249: Predicted next action = retreat, True = retreat
# Prediction 250: Predicted next action = approach, True = approach
# Prediction 251: Predicted next action = retreat, True = hold
# Prediction 252: Predicted next action = place, True = retreat
# Prediction 253: Predicted next action = approach, True = approach
# Prediction 254: Predicted next action = retreat, True = lift
# Prediction 255: Predicted next action = retreat, True = retreat
# Prediction 256: Predicted next action = retreat, True = approach
# Prediction 257: Predicted next action = retreat, True = lift
# Prediction 258: Predicted next action = retreat, True = screw
# Prediction 259: Predicted next action = approach, True = retreat
# Prediction 260: Predicted next action = retreat, True = approach
# Prediction 261: Predicted next action = retreat, True = screw
# Prediction 262: Predicted next action = approach, True = retreat
# Prediction 263: Predicted next action = retreat, True = approach
# Prediction 264: Predicted next action = retreat, True = screw
# Prediction 265: Predicted next action = approach, True = retreat
# Prediction 266: Predicted next action = retreat, True = approach
# Prediction 267: Predicted next action = retreat, True = screw
# Prediction 268: Predicted next action = approach, True = retreat
# Prediction 269: Predicted next action = retreat, True = approach
# Prediction 270: Predicted next action = retreat, True = screw
# Prediction 271: Predicted next action = approach, True = retreat
# Prediction 272: Predicted next action = retreat, True = approach
# Prediction 273: Predicted next action = retreat, True = screw
# Prediction 274: Predicted next action = approach, True = place
# Prediction 275: Predicted next action = retreat, True = retreat
# Prediction 276: Predicted next action = approach, True = approach
# Prediction 277: Predicted next action = retreat, True = hold
# Prediction 278: Predicted next action = place, True = place
# Prediction 279: Predicted next action = retreat, True = retreat
# Prediction 280: Predicted next action = approach, True = approach
# Prediction 281: Predicted next action = retreat, True = lift
# Prediction 282: Predicted next action = retreat, True = idle
# Prediction 283: Predicted next action = approach, True = approach
# Prediction 284: Predicted next action = retreat, True = hammer
# Prediction 285: Predicted next action = place, True = retreat
# Prediction 286: Predicted next action = retreat, True = idle
# Prediction 287: Predicted next action = approach, True = approach
# Prediction 288: Predicted next action = retreat, True = hammer
# Prediction 289: Predicted next action = place, True = place
# Prediction 290: Predicted next action = retreat, True = retreat
# Prediction 291: Predicted next action = approach, True = approach
# Prediction 292: Predicted next action = retreat, True = lift
# Prediction 293: Predicted next action = retreat, True = place
# Prediction 294: Predicted next action = retreat, True = hold
# Prediction 295: Predicted next action = place, True = retreat
# Prediction 296: Predicted next action = retreat, True = approach
# Prediction 297: Predicted next action = retreat, True = hold
# Prediction 298: Predicted next action = place, True = retreat
# Prediction 299: Predicted next action = retreat, True = approach
# Prediction 300: Predicted next action = retreat, True = lift
# Prediction 301: Predicted next action = retreat, True = place
# Prediction 302: Predicted next action = retreat, True = hold
# Prediction 303: Predicted next action = place, True = retreat
# Prediction 304: Predicted next action = retreat, True = approach
# Prediction 305: Predicted next action = retreat, True = hold
# Prediction 306: Predicted next action = place, True = retreat
# Prediction 307: Predicted next action = approach, True = approach
# Prediction 308: Predicted next action = retreat, True = lift
# Prediction 309: Predicted next action = retreat, True = idle
# Prediction 310: Predicted next action = approach, True = approach
# Prediction 311: Predicted next action = retreat, True = hammer
# Prediction 312: Predicted next action = place, True = retreat
# Prediction 313: Predicted next action = retreat, True = idle
# Prediction 314: Predicted next action = approach, True = approach
# Prediction 315: Predicted next action = retreat, True = hammer
# Prediction 316: Predicted next action = place, True = retreat
# Prediction 317: Predicted next action = retreat, True = idle
# Prediction 318: Predicted next action = approach, True = approach
# Prediction 319: Predicted next action = retreat, True = hammer
# Prediction 320: Predicted next action = place, True = place
# Prediction 321: Predicted next action = retreat, True = retreat
# Prediction 322: Predicted next action = approach, True = approach
# Prediction 323: Predicted next action = retreat, True = lift
# Prediction 324: Predicted next action = retreat, True = place
# Prediction 325: Predicted next action = retreat, True = hold
# Prediction 326: Predicted next action = place, True = retreat
# Prediction 327: Predicted next action = retreat, True = approach
# Prediction 328: Predicted next action = retreat, True = lift
# Prediction 329: Predicted next action = retreat, True = place
# Prediction 330: Predicted next action = retreat, True = hold
# Prediction 331: Predicted next action = place, True = retreat
# Prediction 332: Predicted next action = retreat, True = approach
# Prediction 333: Predicted next action = retreat, True = lift
# Prediction 334: Predicted next action = retreat, True = place
# Prediction 335: Predicted next action = retreat, True = hold
# Prediction 336: Predicted next action = place, True = retreat
# Prediction 337: Predicted next action = retreat, True = approach
# Prediction 338: Predicted next action = retreat, True = hold
# Prediction 339: Predicted next action = place, True = retreat
# Prediction 340: Predicted next action = approach, True = approach
# Prediction 341: Predicted next action = retreat, True = lift
# Prediction 342: Predicted next action = retreat, True = saw
# Prediction 343: Predicted next action = place, True = place
# Prediction 344: Predicted next action = retreat, True = retreat
# Prediction 345: Predicted next action = approach, True = approach
# Prediction 346: Predicted next action = retreat, True = hold
# Prediction 347: Predicted next action = place, True = retreat
# Prediction 348: Predicted next action = retreat, True = approach
# Prediction 349: Predicted next action = retreat, True = hold
# Prediction 350: Predicted next action = place, True = retreat
# Prediction 351: Predicted next action = approach, True = approach
# Prediction 352: Predicted next action = retreat, True = lift
# Prediction 353: Predicted next action = retreat, True = saw
# Prediction 354: Predicted next action = place, True = place
# Prediction 355: Predicted next action = retreat, True = retreat
# Prediction 356: Predicted next action = retreat, True = approach
# Prediction 357: Predicted next action = retreat, True = lift
# Prediction 358: Predicted next action = retreat, True = place
# Prediction 359: Predicted next action = retreat, True = retreat
# Prediction 360: Predicted next action = approach, True = approach
# Prediction 361: Predicted next action = retreat, True = hold
# Prediction 362: Predicted next action = place, True = lift
# Prediction 363: Predicted next action = retreat, True = place
# Prediction 364: Predicted next action = retreat, True = retreat
# Prediction 365: Predicted next action = approach, True = approach
# Prediction 366: Predicted next action = retreat, True = lift
# Prediction 367: Predicted next action = retreat, True = stir
# Prediction 368: Predicted next action = place, True = place
# Prediction 369: Predicted next action = retreat, True = retreat
# Prediction 370: Predicted next action = approach, True = approach
# Prediction 371: Predicted next action = retreat, True = hold
# Prediction 372: Predicted next action = place, True = retreat
# Prediction 373: Predicted next action = retreat, True = approach
# Prediction 374: Predicted next action = retreat, True = lift
# Prediction 375: Predicted next action = retreat, True = pour
# Prediction 376: Predicted next action = place, True = place
# Prediction 377: Predicted next action = retreat, True = retreat
# Prediction 378: Predicted next action = retreat, True = approach
# Prediction 379: Predicted next action = retreat, True = hold
# Prediction 380: Predicted next action = place, True = retreat
# Prediction 381: Predicted next action = approach, True = approach
# Prediction 382: Predicted next action = retreat, True = lift
# Prediction 383: Predicted next action = retreat, True = stir
# Prediction 384: Predicted next action = place, True = place
# Prediction 385: Predicted next action = retreat, True = retreat
# Prediction 386: Predicted next action = approach, True = approach
# Prediction 387: Predicted next action = retreat, True = hold
# Prediction 388: Predicted next action = place, True = retreat
# Prediction 389: Predicted next action = retreat, True = approach
# Prediction 390: Predicted next action = retreat, True = lift
# Prediction 391: Predicted next action = retreat, True = pour
# Prediction 392: Predicted next action = place, True = place
# Prediction 393: Predicted next action = retreat, True = retreat
# Prediction 394: Predicted next action = retreat, True = approach
# Prediction 395: Predicted next action = retreat, True = hold
# Prediction 396: Predicted next action = place, True = retreat
# Prediction 397: Predicted next action = approach, True = approach
# Prediction 398: Predicted next action = retreat, True = lift
# Prediction 399: Predicted next action = retreat, True = stir
# Prediction 400: Predicted next action = place, True = place
# Prediction 401: Predicted next action = retreat, True = retreat
# Prediction 402: Predicted next action = approach, True = approach
# Prediction 403: Predicted next action = retreat, True = hold
# Prediction 404: Predicted next action = place, True = retreat
# Prediction 405: Predicted next action = retreat, True = approach
# Prediction 406: Predicted next action = retreat, True = lift
# Prediction 407: Predicted next action = retreat, True = pour
# Prediction 408: Predicted next action = place, True = place
# Prediction 409: Predicted next action = retreat, True = retreat
# Prediction 410: Predicted next action = retreat, True = approach
# Prediction 411: Predicted next action = retreat, True = hold
# Prediction 412: Predicted next action = place, True = retreat
# Prediction 413: Predicted next action = approach, True = approach
# Prediction 414: Predicted next action = retreat, True = lift
# Prediction 415: Predicted next action = retreat, True = stir
# Prediction 416: Predicted next action = place, True = place
# Prediction 417: Predicted next action = retreat, True = retreat
# Prediction 418: Predicted next action = approach, True = approach
# Prediction 419: Predicted next action = retreat, True = hold
# Prediction 420: Predicted next action = place, True = retreat
# Prediction 421: Predicted next action = retreat, True = approach
# Prediction 422: Predicted next action = retreat, True = lift
# Prediction 423: Predicted next action = retreat, True = pour
# Prediction 424: Predicted next action = place, True = place
# Prediction 425: Predicted next action = retreat, True = retreat
# Prediction 426: Predicted next action = retreat, True = approach
# Prediction 427: Predicted next action = retreat, True = hold
# Prediction 428: Predicted next action = place, True = retreat
# Prediction 429: Predicted next action = approach, True = approach
# Prediction 430: Predicted next action = retreat, True = lift
# Prediction 431: Predicted next action = retreat, True = hold
# Prediction 432: Predicted next action = place, True = lift
# Prediction 433: Predicted next action = retreat, True = drink
# Prediction 434: Predicted next action = place, True = place
# Prediction 435: Predicted next action = retreat, True = retreat
# Prediction 436: Predicted next action = approach, True = approach
# Prediction 437: Predicted next action = retreat, True = lift
# Prediction 438: Predicted next action = retreat, True = pour
# Prediction 439: Predicted next action = place, True = place
# Prediction 440: Predicted next action = retreat, True = retreat
# Prediction 441: Predicted next action = approach, True = approach
# Prediction 442: Predicted next action = retreat, True = lift
# Prediction 443: Predicted next action = retreat, True = hold
# Prediction 444: Predicted next action = place, True = lift
# Prediction 445: Predicted next action = retreat, True = drink
# Prediction 446: Predicted next action = place, True = place
# Prediction 447: Predicted next action = retreat, True = retreat
# Prediction 448: Predicted next action = approach, True = approach
# Prediction 449: Predicted next action = retreat, True = lift
# Prediction 450: Predicted next action = retreat, True = pour
# Prediction 451: Predicted next action = place, True = place
# Prediction 452: Predicted next action = retreat, True = retreat
# Prediction 453: Predicted next action = approach, True = approach
# Prediction 454: Predicted next action = retreat, True = wipe
# Prediction 455: Predicted next action = retreat, True = retreat
# Prediction 456: Predicted next action = approach, True = approach
# Prediction 457: Predicted next action = retreat, True = wipe
# Prediction 458: Predicted next action = retreat, True = retreat
# Prediction 459: Predicted next action = approach, True = approach
# Prediction 460: Predicted next action = retreat, True = lift
# Prediction 461: Predicted next action = retreat, True = hold
# Prediction 462: Predicted next action = place, True = place
# Prediction 463: Predicted next action = retreat, True = retreat
# Prediction 464: Predicted next action = retreat, True = approach
# Prediction 465: Predicted next action = retreat, True = lift
# Prediction 466: Predicted next action = retreat, True = hold
# Prediction 467: Predicted next action = place, True = place
# Prediction 468: Predicted next action = retreat, True = retreat
# Prediction 469: Predicted next action = approach, True = approach
# Prediction 470: Predicted next action = retreat, True = lift
# Prediction 471: Predicted next action = retreat, True = cut
# Prediction 472: Predicted next action = place, True = retreat
# Prediction 473: Predicted next action = retreat, True = approach
# Prediction 474: Predicted next action = retreat, True = lift
# Prediction 475: Predicted next action = retreat, True = approach
# Prediction 476: Predicted next action = retreat, True = pour
# Prediction 477: Predicted next action = place, True = place
# Prediction 478: Predicted next action = retreat, True = retreat
# Prediction 479: Predicted next action = retreat, True = approach
# Prediction 480: Predicted next action = retreat, True = hold
# Prediction 481: Predicted next action = place, True = retreat
# Prediction 482: Predicted next action = retreat, True = idle
# Prediction 483: Predicted next action = approach, True = approach
# Prediction 484: Predicted next action = retreat, True = lift
# Prediction 485: Predicted next action = retreat, True = pour
# Prediction 486: Predicted next action = place, True = place
# Prediction 487: Predicted next action = retreat, True = retreat
# Prediction 488: Predicted next action = approach, True = approach
# Prediction 489: Predicted next action = retreat, True = hold
# Prediction 490: Predicted next action = place, True = retreat
# Prediction 491: Predicted next action = retreat, True = approach
# Prediction 492: Predicted next action = retreat, True = lift
# Prediction 493: Predicted next action = retreat, True = hold
# Prediction 494: Predicted next action = place, True = place
# Prediction 495: Predicted next action = retreat, True = retreat
# Prediction 496: Predicted next action = retreat, True = approach
# Prediction 497: Predicted next action = retreat, True = lift
# Prediction 498: Predicted next action = retreat, True = pour
# Prediction 499: Predicted next action = place, True = place
# Prediction 500: Predicted next action = retreat, True = retreat
# Prediction 501: Predicted next action = approach, True = approach
# Prediction 502: Predicted next action = retreat, True = lift
# Prediction 503: Predicted next action = retreat, True = cut
# Prediction 504: Predicted next action = place, True = retreat
# Prediction 505: Predicted next action = retreat, True = approach
# Prediction 506: Predicted next action = retreat, True = lift
# Prediction 507: Predicted next action = retreat, True = approach
# Prediction 508: Predicted next action = retreat, True = place
# Prediction 509: Predicted next action = retreat, True = retreat
# Prediction 510: Predicted next action = retreat, True = approach
# Prediction 511: Predicted next action = retreat, True = hold
# Prediction 512: Predicted next action = place, True = retreat
# Prediction 513: Predicted next action = retreat, True = approach
# Prediction 514: Predicted next action = retreat, True = lift
# Prediction 515: Predicted next action = retreat, True = pour
# Prediction 516: Predicted next action = place, True = place
# Prediction 517: Predicted next action = retreat, True = retreat
# Prediction 518: Predicted next action = approach, True = approach
# Prediction 519: Predicted next action = retreat, True = hold
# Prediction 520: Predicted next action = place, True = retreat
# Prediction 521: Predicted next action = retreat, True = approach
# Prediction 522: Predicted next action = retreat, True = lift
# Prediction 523: Predicted next action = retreat, True = hold
# Prediction 524: Predicted next action = place, True = place
# Prediction 525: Predicted next action = retreat, True = retreat
# Prediction 526: Predicted next action = retreat, True = approach
# Prediction 527: Predicted next action = retreat, True = lift
# Prediction 528: Predicted next action = retreat, True = pour
# Prediction 529: Predicted next action = place, True = place
# Prediction 530: Predicted next action = retreat, True = retreat
# Prediction 531: Predicted next action = retreat, True = approach
# Prediction 532: Predicted next action = retreat, True = hold
# Prediction 533: Predicted next action = place, True = retreat
# Prediction 534: Predicted next action = approach, True = approach
# Prediction 535: Predicted next action = retreat, True = lift
# Prediction 536: Predicted next action = retreat, True = screw
# Prediction 537: Predicted next action = approach, True = retreat
# Prediction 538: Predicted next action = retreat, True = approach
# Prediction 539: Predicted next action = retreat, True = screw
# Prediction 540: Predicted next action = approach, True = place
# Prediction 541: Predicted next action = retreat, True = retreat
# Prediction 542: Predicted next action = approach, True = approach
# Prediction 543: Predicted next action = retreat, True = hold
# Prediction 544: Predicted next action = place, True = retreat
# Prediction 545: Predicted next action = retreat, True = approach
# Prediction 546: Predicted next action = retreat, True = lift
# Prediction 547: Predicted next action = retreat, True = place
# Prediction 548: Predicted next action = retreat, True = retreat
# Prediction 549: Predicted next action = retreat, True = approach
# Prediction 550: Predicted next action = retreat, True = hold
# Prediction 551: Predicted next action = place, True = retreat
# Prediction 552: Predicted next action = retreat, True = approach
# Prediction 553: Predicted next action = retreat, True = lift
# Prediction 554: Predicted next action = retreat, True = place
# Prediction 555: Predicted next action = retreat, True = retreat
# Prediction 556: Predicted next action = approach, True = approach
# Prediction 557: Predicted next action = retreat, True = lift
# Prediction 558: Predicted next action = retreat, True = screw
# Prediction 559: Predicted next action = approach, True = retreat
# Prediction 560: Predicted next action = retreat, True = approach
# Prediction 561: Predicted next action = retreat, True = screw
# Prediction 562: Predicted next action = approach, True = place
# Prediction 563: Predicted next action = retreat, True = retreat
# Prediction 564: Predicted next action = approach, True = approach
# Prediction 565: Predicted next action = retreat, True = hold
# Prediction 566: Predicted next action = place, True = retreat
# Prediction 567: Predicted next action = retreat, True = approach
# Prediction 568: Predicted next action = retreat, True = lift
# Prediction 569: Predicted next action = retreat, True = place
# Prediction 570: Predicted next action = retreat, True = retreat
# Prediction 571: Predicted next action = retreat, True = approach
# Prediction 572: Predicted next action = retreat, True = hold
# Prediction 573: Predicted next action = place, True = retreat
# Prediction 574: Predicted next action = retreat, True = approach
# Prediction 575: Predicted next action = retreat, True = lift
# Prediction 576: Predicted next action = retreat, True = place
# Prediction 577: Predicted next action = retreat, True = retreat
# Prediction 578: Predicted next action = approach, True = approach
# Prediction 579: Predicted next action = retreat, True = lift
# Prediction 580: Predicted next action = retreat, True = hold
# Prediction 581: Predicted next action = place, True = retreat
# Prediction 582: Predicted next action = retreat, True = approach
# Prediction 583: Predicted next action = retreat, True = screw
# Prediction 584: Predicted next action = approach, True = retreat
# Prediction 585: Predicted next action = retreat, True = approach
# Prediction 586: Predicted next action = retreat, True = screw
# Prediction 587: Predicted next action = approach, True = place
# Prediction 588: Predicted next action = retreat, True = retreat
# Prediction 589: Predicted next action = approach, True = approach
# Prediction 590: Predicted next action = retreat, True = lift
# Prediction 591: Predicted next action = retreat, True = hold
# Prediction 592: Predicted next action = place, True = place
# Prediction 593: Predicted next action = retreat, True = retreat
# Prediction 594: Predicted next action = approach, True = approach
# Prediction 595: Predicted next action = retreat, True = lift
# Prediction 596: Predicted next action = retreat, True = hold
# Prediction 597: Predicted next action = place, True = retreat
# Prediction 598: Predicted next action = retreat, True = approach
# Prediction 599: Predicted next action = retreat, True = screw
# Prediction 600: Predicted next action = approach, True = retreat
# Prediction 601: Predicted next action = retreat, True = approach
# Prediction 602: Predicted next action = retreat, True = screw
# Prediction 603: Predicted next action = approach, True = place
# Prediction 604: Predicted next action = retreat, True = retreat
# Prediction 605: Predicted next action = approach, True = approach
# Prediction 606: Predicted next action = retreat, True = lift
# Prediction 607: Predicted next action = retreat, True = hold
# Prediction 608: Predicted next action = place, True = place
# Prediction 609: Predicted next action = retreat, True = retreat
# Prediction 610: Predicted next action = approach, True = approach
# Prediction 611: Predicted next action = retreat, True = lift
# Prediction 612: Predicted next action = retreat, True = hammer
# Prediction 613: Predicted next action = place, True = retreat
# Prediction 614: Predicted next action = retreat, True = idle
# Prediction 615: Predicted next action = approach, True = approach
# Prediction 616: Predicted next action = retreat, True = hammer
# Prediction 617: Predicted next action = place, True = place
# Prediction 618: Predicted next action = retreat, True = retreat
# Prediction 619: Predicted next action = approach, True = approach
# Prediction 620: Predicted next action = retreat, True = lift
# Prediction 621: Predicted next action = retreat, True = place
# Prediction 622: Predicted next action = retreat, True = hold
# Prediction 623: Predicted next action = place, True = retreat
# Prediction 624: Predicted next action = retreat, True = approach
# Prediction 625: Predicted next action = retreat, True = hold
# Prediction 626: Predicted next action = place, True = retreat
# Prediction 627: Predicted next action = retreat, True = approach
# Prediction 628: Predicted next action = retreat, True = lift
# Prediction 629: Predicted next action = retreat, True = place
# Prediction 630: Predicted next action = retreat, True = hold
# Prediction 631: Predicted next action = place, True = retreat
# Prediction 632: Predicted next action = retreat, True = approach
# Prediction 633: Predicted next action = retreat, True = hold
# Prediction 634: Predicted next action = place, True = retreat
# Prediction 635: Predicted next action = approach, True = approach
# Prediction 636: Predicted next action = retreat, True = lift
# Prediction 637: Predicted next action = retreat, True = idle
# Prediction 638: Predicted next action = approach, True = approach
# Prediction 639: Predicted next action = retreat, True = hammer
# Prediction 640: Predicted next action = place, True = idle
# Prediction 641: Predicted next action = approach, True = approach
# Prediction 642: Predicted next action = retreat, True = hammer
# Prediction 643: Predicted next action = place, True = place
# Prediction 644: Predicted next action = retreat, True = retreat
# Prediction 645: Predicted next action = approach, True = approach
# Prediction 646: Predicted next action = retreat, True = lift
# Prediction 647: Predicted next action = retreat, True = place
# Prediction 648: Predicted next action = retreat, True = hold
# Prediction 649: Predicted next action = place, True = retreat
# Prediction 650: Predicted next action = retreat, True = approach
# Prediction 651: Predicted next action = retreat, True = hold
# Prediction 652: Predicted next action = place, True = retreat
# Prediction 653: Predicted next action = retreat, True = approach
# Prediction 654: Predicted next action = retreat, True = lift
# Prediction 655: Predicted next action = retreat, True = place
# Prediction 656: Predicted next action = retreat, True = hold
# Prediction 657: Predicted next action = place, True = retreat
# Prediction 658: Predicted next action = retreat, True = approach
# Prediction 659: Predicted next action = retreat, True = hold
# Prediction 660: Predicted next action = place, True = retreat
# Prediction 661: Predicted next action = approach, True = approach
# Prediction 662: Predicted next action = retreat, True = lift
# Prediction 663: Predicted next action = retreat, True = saw
# Prediction 664: Predicted next action = place, True = place
# Prediction 665: Predicted next action = retreat, True = retreat
# Prediction 666: Predicted next action = retreat, True = approach
# Prediction 667: Predicted next action = retreat, True = hold
# Prediction 668: Predicted next action = place, True = place
# Prediction 669: Predicted next action = retreat, True = retreat
# Prediction 670: Predicted next action = approach, True = approach
# Prediction 671: Predicted next action = retreat, True = hold
# Prediction 672: Predicted next action = place, True = lift
# Prediction 673: Predicted next action = retreat, True = hold
# Prediction 674: Predicted next action = place, True = place
# Prediction 675: Predicted next action = retreat, True = retreat
# Prediction 676: Predicted next action = approach, True = approach
# Prediction 677: Predicted next action = retreat, True = lift
# Prediction 678: Predicted next action = retreat, True = saw
# Prediction 679: Predicted next action = place, True = place
# Prediction 680: Predicted next action = retreat, True = retreat
# Prediction 681: Predicted next action = retreat, True = approach
# Prediction 682: Predicted next action = retreat, True = hold
# Prediction 683: Predicted next action = place, True = place
# Prediction 684: Predicted next action = approach, True = approach
# Prediction 685: Predicted next action = retreat, True = hold
# Prediction 686: Predicted next action = place, True = lift
# Prediction 687: Predicted next action = retreat, True = hold
# Prediction 688: Predicted next action = place, True = place
# Prediction 689: Predicted next action = retreat, True = retreat
# Prediction 690: Predicted next action = approach, True = approach
# Prediction 691: Predicted next action = retreat, True = hold
# Prediction 692: Predicted next action = place, True = retreat
# Prediction 693: Predicted next action = retreat, True = approach
# Prediction 694: Predicted next action = retreat, True = lift
# Prediction 695: Predicted next action = retreat, True = pour
# Prediction 696: Predicted next action = place, True = place
# Prediction 697: Predicted next action = retreat, True = retreat
# Prediction 698: Predicted next action = retreat, True = approach
# Prediction 699: Predicted next action = retreat, True = hold
# Prediction 700: Predicted next action = place, True = retreat
# Prediction 701: Predicted next action = approach, True = approach
# Prediction 702: Predicted next action = retreat, True = lift
# Prediction 703: Predicted next action = retreat, True = stir
# Prediction 704: Predicted next action = place, True = place
# Prediction 705: Predicted next action = retreat, True = retreat
# Prediction 706: Predicted next action = approach, True = approach
# Prediction 707: Predicted next action = retreat, True = hold
# Prediction 708: Predicted next action = place, True = retreat
# Prediction 709: Predicted next action = retreat, True = approach
# Prediction 710: Predicted next action = retreat, True = lift
# Prediction 711: Predicted next action = retreat, True = pour
# Prediction 712: Predicted next action = place, True = place
# Prediction 713: Predicted next action = retreat, True = retreat
# Prediction 714: Predicted next action = retreat, True = approach
# Prediction 715: Predicted next action = retreat, True = hold
# Prediction 716: Predicted next action = place, True = retreat
# Prediction 717: Predicted next action = approach, True = approach
# Prediction 718: Predicted next action = retreat, True = lift
# Prediction 719: Predicted next action = retreat, True = stir
# Prediction 720: Predicted next action = place, True = place
# Prediction 721: Predicted next action = retreat, True = retreat
# Prediction 722: Predicted next action = approach, True = approach
# Prediction 723: Predicted next action = retreat, True = hold
# Prediction 724: Predicted next action = place, True = retreat
# Prediction 725: Predicted next action = retreat, True = approach
# Prediction 726: Predicted next action = retreat, True = lift
# Prediction 727: Predicted next action = retreat, True = pour
# Prediction 728: Predicted next action = place, True = place
# Prediction 729: Predicted next action = retreat, True = retreat
# Prediction 730: Predicted next action = retreat, True = approach
# Prediction 731: Predicted next action = retreat, True = hold
# Prediction 732: Predicted next action = place, True = retreat
# Prediction 733: Predicted next action = approach, True = approach
# Prediction 734: Predicted next action = retreat, True = lift
# Prediction 735: Predicted next action = retreat, True = stir
# Prediction 736: Predicted next action = place, True = place
# Prediction 737: Predicted next action = retreat, True = retreat
# Prediction 738: Predicted next action = approach, True = approach
# Prediction 739: Predicted next action = retreat, True = hold
# Prediction 740: Predicted next action = place, True = retreat
# Prediction 741: Predicted next action = retreat, True = approach
# Prediction 742: Predicted next action = retreat, True = lift
# Prediction 743: Predicted next action = retreat, True = pour
# Prediction 744: Predicted next action = place, True = place
# Prediction 745: Predicted next action = retreat, True = retreat
# Prediction 746: Predicted next action = retreat, True = approach
# Prediction 747: Predicted next action = retreat, True = hold
# Prediction 748: Predicted next action = place, True = retreat
# Prediction 749: Predicted next action = approach, True = approach
# Prediction 750: Predicted next action = retreat, True = lift
# Prediction 751: Predicted next action = retreat, True = stir
# Prediction 752: Predicted next action = place, True = retreat
# Prediction 753: Predicted next action = retreat, True = idle
# Prediction 754: Predicted next action = approach, True = approach
# Prediction 755: Predicted next action = retreat, True = stir
# Prediction 756: Predicted next action = place, True = place
# Prediction 757: Predicted next action = retreat, True = retreat
# Prediction 758: Predicted next action = approach, True = approach
# Prediction 759: Predicted next action = retreat, True = lift
# Prediction 760: Predicted next action = retreat, True = hold
# Prediction 761: Predicted next action = place, True = retreat
# Prediction 762: Predicted next action = approach, True = approach
# Prediction 763: Predicted next action = retreat, True = lift
# Prediction 764: Predicted next action = retreat, True = pour
# Prediction 765: Predicted next action = place, True = place
# Prediction 766: Predicted next action = retreat, True = retreat
# Prediction 767: Predicted next action = retreat, True = approach
# Prediction 768: Predicted next action = retreat, True = lift
# ...
# Prediction 1876: Predicted next action = retreat, True = hold
# Prediction 1877: Predicted next action = place, True = place
# Prediction 1878: Predicted next action = retreat, True = retreat
# Prediction 1879: Predicted next action = approach, True = approach
# Prediction 1880: Predicted next action = retreat, True = wipe
# Prediction 1881: Predicted next action = retreat, True = retreat
# Prediction 1882: Predicted next action = approach, True = approach
# Prediction 1883: Predicted next action = retreat, True = lift
# Prediction 1884: Predicted next action = retreat, True = hold
# Prediction 1885: Predicted next action = place, True = place
# Prediction 1886: Predicted next action = retreat, True = retreat
# Prediction 1887: Predicted next action = retreat, True = approach
# Prediction 1888: Predicted next action = retreat, True = lift
# Prediction 1889: Predicted next action = retreat, True = hold
# Prediction 1890: Predicted next action = place, True = place
# Prediction 1891: Predicted next action = retreat, True = retreat
# Prediction 1892: Predicted next action = retreat, True = approach
# Prediction 1893: Predicted next action = retreat, True = lift
# Prediction 1894: Predicted next action = retreat, True = hold
# Prediction 1895: Predicted next action = place, True = place
# Prediction 1896: Predicted next action = retreat, True = retreat
# Prediction 1897: Predicted next action = approach, True = approach
# Prediction 1898: Predicted next action = retreat, True = lift
# Prediction 1899: Predicted next action = retreat, True = cut
# Prediction 1900: Predicted next action = place, True = retreat
# Prediction 1901: Predicted next action = retreat, True = approach
# Prediction 1902: Predicted next action = retreat, True = lift
# Prediction 1903: Predicted next action = retreat, True = hold
# Prediction 1904: Predicted next action = place, True = place
# Prediction 1905: Predicted next action = retreat, True = retreat
# Prediction 1906: Predicted next action = retreat, True = approach
# Prediction 1907: Predicted next action = retreat, True = lift
# Prediction 1908: Predicted next action = retreat, True = pour
# Prediction 1909: Predicted next action = place, True = place
# Prediction 1910: Predicted next action = retreat, True = retreat
# Prediction 1911: Predicted next action = retreat, True = approach
# Prediction 1912: Predicted next action = retreat, True = lift
# Prediction 1913: Predicted next action = retreat, True = pour
# Prediction 1914: Predicted next action = place, True = place
# Prediction 1915: Predicted next action = retreat, True = retreat
# Prediction 1916: Predicted next action = approach, True = approach
# Prediction 1917: Predicted next action = retreat, True = hold
# Prediction 1918: Predicted next action = place, True = retreat
# Prediction 1919: Predicted next action = retreat, True = approach
# Prediction 1920: Predicted next action = retreat, True = idle
# Prediction 1921: Predicted next action = approach, True = approach
# Prediction 1922: Predicted next action = retreat, True = pour
# Prediction 1923: Predicted next action = place, True = place
# Prediction 1924: Predicted next action = retreat, True = retreat
# Prediction 1925: Predicted next action = retreat, True = approach
# Prediction 1926: Predicted next action = retreat, True = hold
# Prediction 1927: Predicted next action = place, True = retreat
# Prediction 1928: Predicted next action = approach, True = approach
# Prediction 1929: Predicted next action = retreat, True = hold
# Prediction 1930: Predicted next action = place, True = retreat
# Prediction 1931: Predicted next action = retreat, True = approach
# Prediction 1932: Predicted next action = retreat, True = lift
# Prediction 1933: Predicted next action = retreat, True = cut
# Prediction 1934: Predicted next action = place, True = retreat
# Prediction 1935: Predicted next action = retreat, True = approach
# Prediction 1936: Predicted next action = retreat, True = lift
# Prediction 1937: Predicted next action = retreat, True = hold
# Prediction 1938: Predicted next action = place, True = place
# Prediction 1939: Predicted next action = retreat, True = retreat
# Prediction 1940: Predicted next action = retreat, True = approach
# Prediction 1941: Predicted next action = retreat, True = lift
# Prediction 1942: Predicted next action = retreat, True = pour
# Prediction 1943: Predicted next action = place, True = place
# Prediction 1944: Predicted next action = retreat, True = retreat
# Prediction 1945: Predicted next action = approach, True = approach
# Prediction 1946: Predicted next action = retreat, True = lift
# Prediction 1947: Predicted next action = retreat, True = pour
# Prediction 1948: Predicted next action = place, True = place
# Prediction 1949: Predicted next action = retreat, True = retreat
# Prediction 1950: Predicted next action = retreat, True = approach
# Prediction 1951: Predicted next action = retreat, True = hold
# Prediction 1952: Predicted next action = place, True = retreat
# Prediction 1953: Predicted next action = retreat, True = approach
# Prediction 1954: Predicted next action = retreat, True = idle
# Prediction 1955: Predicted next action = approach, True = approach
# Prediction 1956: Predicted next action = retreat, True = pour
# Prediction 1957: Predicted next action = place, True = place
# Prediction 1958: Predicted next action = retreat, True = retreat
# Prediction 1959: Predicted next action = retreat, True = approach
# Prediction 1960: Predicted next action = retreat, True = hold
# Prediction 1961: Predicted next action = place, True = retreat
# Prediction 1962: Predicted next action = approach, True = approach
# Prediction 1963: Predicted next action = retreat, True = lift
# Prediction 1964: Predicted next action = retreat, True = screw
# Prediction 1965: Predicted next action = approach, True = retreat
# Prediction 1966: Predicted next action = retreat, True = approach
# Prediction 1967: Predicted next action = retreat, True = lift
# Prediction 1968: Predicted next action = retreat, True = place
# Prediction 1969: Predicted next action = retreat, True = retreat
# Prediction 1970: Predicted next action = retreat, True = approach
# Prediction 1971: Predicted next action = retreat, True = screw
# Prediction 1972: Predicted next action = approach, True = retreat
# Prediction 1973: Predicted next action = retreat, True = approach
# Prediction 1974: Predicted next action = retreat, True = lift
# Prediction 1975: Predicted next action = retreat, True = place
# Prediction 1976: Predicted next action = retreat, True = place
# Prediction 1977: Predicted next action = retreat, True = retreat
# Prediction 1978: Predicted next action = approach, True = approach
# Prediction 1979: Predicted next action = retreat, True = hold
# Prediction 1980: Predicted next action = place, True = retreat
# Prediction 1981: Predicted next action = approach, True = approach
# Prediction 1982: Predicted next action = retreat, True = lift
# Prediction 1983: Predicted next action = retreat, True = screw
# Prediction 1984: Predicted next action = approach, True = retreat
# Prediction 1985: Predicted next action = retreat, True = approach
# Prediction 1986: Predicted next action = retreat, True = lift
# Prediction 1987: Predicted next action = retreat, True = place
# Prediction 1988: Predicted next action = retreat, True = retreat
# Prediction 1989: Predicted next action = retreat, True = approach
# Prediction 1990: Predicted next action = retreat, True = screw
# Prediction 1991: Predicted next action = approach, True = retreat
# Prediction 1992: Predicted next action = retreat, True = approach
# Prediction 1993: Predicted next action = retreat, True = lift
# Prediction 1994: Predicted next action = retreat, True = place
# Prediction 1995: Predicted next action = retreat, True = place
# Prediction 1996: Predicted next action = retreat, True = retreat
# Prediction 1997: Predicted next action = approach, True = approach
# Prediction 1998: Predicted next action = retreat, True = hold
# Prediction 1999: Predicted next action = place, True = retreat
# Prediction 2000: Predicted next action = approach, True = approach
# Prediction 2001: Predicted next action = retreat, True = lift
# Prediction 2002: Predicted next action = retreat, True = approach
# Prediction 2003: Predicted next action = retreat, True = lift
# Prediction 2004: Predicted next action = retreat, True = retreat
# Prediction 2005: Predicted next action = retreat, True = approach
# Prediction 2006: Predicted next action = retreat, True = screw
# Prediction 2007: Predicted next action = approach, True = retreat
# Prediction 2008: Predicted next action = retreat, True = approach
# Prediction 2009: Predicted next action = retreat, True = lift
# Prediction 2010: Predicted next action = retreat, True = place
# Prediction 2011: Predicted next action = retreat, True = retreat
# Prediction 2012: Predicted next action = retreat, True = approach
# Prediction 2013: Predicted next action = retreat, True = hold
# Prediction 2014: Predicted next action = place, True = retreat
# Prediction 2015: Predicted next action = retreat, True = approach
# Prediction 2016: Predicted next action = retreat, True = screw
# Prediction 2017: Predicted next action = approach, True = retreat
# Prediction 2018: Predicted next action = retreat, True = approach
# Prediction 2019: Predicted next action = retreat, True = lift
# Prediction 2020: Predicted next action = retreat, True = place
# Prediction 2021: Predicted next action = retreat, True = place
# Prediction 2022: Predicted next action = retreat, True = retreat
# Prediction 2023: Predicted next action = approach, True = approach
# Prediction 2024: Predicted next action = retreat, True = lift
# Prediction 2025: Predicted next action = retreat, True = hold
# Prediction 2026: Predicted next action = place, True = place
# Prediction 2027: Predicted next action = retreat, True = retreat
# Prediction 2028: Predicted next action = approach, True = approach
# Prediction 2029: Predicted next action = retreat, True = lift
# Prediction 2030: Predicted next action = retreat, True = retreat
# Prediction 2031: Predicted next action = retreat, True = approach
# Prediction 2032: Predicted next action = retreat, True = lift
# Prediction 2033: Predicted next action = retreat, True = screw
# Prediction 2034: Predicted next action = approach, True = retreat
# Prediction 2035: Predicted next action = retreat, True = approach
# Prediction 2036: Predicted next action = retreat, True = lift
# Prediction 2037: Predicted next action = retreat, True = place
# Prediction 2038: Predicted next action = retreat, True = retreat
# Prediction 2039: Predicted next action = retreat, True = approach
# Prediction 2040: Predicted next action = retreat, True = hold
# Prediction 2041: Predicted next action = place, True = retreat
# Prediction 2042: Predicted next action = retreat, True = approach
# Prediction 2043: Predicted next action = retreat, True = screw
# Prediction 2044: Predicted next action = approach, True = retreat
# Prediction 2045: Predicted next action = retreat, True = retreat
# Prediction 2046: Predicted next action = retreat, True = lift
# Prediction 2047: Predicted next action = retreat, True = place
# Prediction 2048: Predicted next action = retreat, True = place
# Prediction 2049: Predicted next action = retreat, True = retreat
# Prediction 2050: Predicted next action = approach, True = approach
# Prediction 2051: Predicted next action = retreat, True = lift
# Prediction 2052: Predicted next action = retreat, True = hold
# Prediction 2053: Predicted next action = place, True = place
# Prediction 2054: Predicted next action = retreat, True = retreat
# Prediction 2055: Predicted next action = approach, True = approach
# Prediction 2056: Predicted next action = retreat, True = hold
# Prediction 2057: Predicted next action = place, True = retreat
# Prediction 2058: Predicted next action = retreat, True = approach
# Prediction 2059: Predicted next action = retreat, True = lift
# Prediction 2060: Predicted next action = retreat, True = hammer
# Prediction 2061: Predicted next action = place, True = retreat
# Prediction 2062: Predicted next action = retreat, True = idle
# Prediction 2063: Predicted next action = approach, True = approach
# Prediction 2064: Predicted next action = retreat, True = hammer
# Prediction 2065: Predicted next action = place, True = place
# Prediction 2066: Predicted next action = retreat, True = retreat
# Prediction 2067: Predicted next action = approach, True = approach
# Prediction 2068: Predicted next action = retreat, True = lift
# Prediction 2069: Predicted next action = retreat, True = retreat
# Prediction 2070: Predicted next action = retreat, True = approach
# Prediction 2071: Predicted next action = retreat, True = hold
# Prediction 2072: Predicted next action = place, True = place
# Prediction 2073: Predicted next action = retreat, True = hold
# Prediction 2074: Predicted next action = place, True = retreat
# Prediction 2075: Predicted next action = retreat, True = approach
# Prediction 2076: Predicted next action = retreat, True = hold
# Prediction 2077: Predicted next action = place, True = retreat
# Prediction 2078: Predicted next action = retreat, True = approach
# Prediction 2079: Predicted next action = retreat, True = lift
# Prediction 2080: Predicted next action = retreat, True = place
# Prediction 2081: Predicted next action = retreat, True = hold
# Prediction 2082: Predicted next action = place, True = retreat
# Prediction 2083: Predicted next action = retreat, True = approach
# Prediction 2084: Predicted next action = retreat, True = hold
# Prediction 2085: Predicted next action = place, True = retreat
# Prediction 2086: Predicted next action = approach, True = approach
# Prediction 2087: Predicted next action = retreat, True = lift
# Prediction 2088: Predicted next action = retreat, True = hammer
# Prediction 2089: Predicted next action = place, True = retreat
# Prediction 2090: Predicted next action = retreat, True = idle
# Prediction 2091: Predicted next action = approach, True = approach
# Prediction 2092: Predicted next action = retreat, True = hammer
# Prediction 2093: Predicted next action = place, True = place
# Prediction 2094: Predicted next action = retreat, True = retreat
# Prediction 2095: Predicted next action = approach, True = approach
# Prediction 2096: Predicted next action = retreat, True = lift
# Prediction 2097: Predicted next action = retreat, True = place
# Prediction 2098: Predicted next action = retreat, True = hold
# Prediction 2099: Predicted next action = place, True = retreat
# Prediction 2100: Predicted next action = retreat, True = approach
# Prediction 2101: Predicted next action = retreat, True = lift
# Prediction 2102: Predicted next action = retreat, True = place
# Prediction 2103: Predicted next action = retreat, True = hold
# Prediction 2104: Predicted next action = place, True = retreat
# Prediction 2105: Predicted next action = approach, True = approach
# Prediction 2106: Predicted next action = retreat, True = lift
# Prediction 2107: Predicted next action = retreat, True = saw
# Prediction 2108: Predicted next action = place, True = place
# Prediction 2109: Predicted next action = retreat, True = retreat
# Prediction 2110: Predicted next action = retreat, True = approach
# Prediction 2111: Predicted next action = retreat, True = hold
# Prediction 2112: Predicted next action = place, True = retreat
# Prediction 2113: Predicted next action = approach, True = approach
# Prediction 2114: Predicted next action = retreat, True = hold
# Prediction 2115: Predicted next action = place, True = retreat
# Prediction 2116: Predicted next action = approach, True = approach
# Prediction 2117: Predicted next action = retreat, True = lift
# Prediction 2118: Predicted next action = retreat, True = saw
# Prediction 2119: Predicted next action = place, True = place
# Prediction 2120: Predicted next action = retreat, True = retreat
# Prediction 2121: Predicted next action = retreat, True = approach
# Prediction 2122: Predicted next action = retreat, True = hold
# Prediction 2123: Predicted next action = place, True = retreat
# Prediction 2124: Predicted next action = approach, True = approach
# Prediction 2125: Predicted next action = retreat, True = hold
# Prediction 2126: Predicted next action = place, True = retreat

# %% [markdown]
# ### TransE parent action

# %%
model_version = "parentAction_transe_word_350epochs"
# model_version = "parentAction_RotatE_word_200epochs"
trained_model_path = f"doctests/{model_version}/trained_model.pkl"
model = torch.load(trained_model_path)

triples_factory = TriplesFactory.from_path_binary(f"doctests/{model_version}/training_triples")
entity_to_id = triples_factory.entity_to_id
entity_id_to_label = triples_factory.entity_id_to_label
relation_to_id = triples_factory.relation_to_id

test_set = np.array([triple for triple in test_triplets if 'has_element' in triple])
mapped_test_data = np.array([[entity_to_id[id_to_utterance[h]], relation_to_id[r], entity_to_id[id_to_utterance[t]]] for h, r, t in test_set])

# %%
true_labels = mapped_test_data[:, 0]
print("true_labels", true_labels)
rel_tail = mapped_test_data[:, 1:]
print("rel_tail", rel_tail)

all_scores = model.predict_h(rt_batch=torch.tensor(rel_tail))
predicted_heads= [scores.argmax().item() for scores in all_scores]

sum(predicted_heads == true_labels)/len(true_labels)*100
# Out:
# true_labels [29 29 29 ... 37 37 37]
# rel_tail [[ 1 12]
#  [ 1  0]
#  [ 1 14]
#  ...
#  [ 1  0]
#  [ 1 11]
#  [ 1 17]]
# 12.174284493806066

# %%
df = []
for index in range (len(test_set)):
    parend_id = test_set[index][0]
    pred = entity_id_to_label[predicted_heads[index]]
    df.append((parend_id, pred))

# %%
df1 = pd.DataFrame(df).groupby(0).agg(list).reset_index()
df1.head()
# Out:
#                           0                                                  1
# 0  668f64fb8cc61c379809bfe8  [task_9_w_sawing, task_4_k_wiping, task_8_w_ha...
# 1  668f64fb8cc61c379809bfff  [task_9_w_sawing, task_4_k_wiping, task_8_w_ha...
# 2  668f64fb8cc61c379809c0c7  [task_9_w_sawing, task_4_k_wiping, task_8_w_ha...
# 3  668f64fb8cc61c379809c0dd  [task_9_w_sawing, task_4_k_wiping, task_8_w_ha...
# 4  668f64fb8cc61c379809c182  [task_9_w_sawing, task_4_k_wiping, task_8_w_ha...

# %%
df1[1] = df1[1].apply(lambda x: max(collections.Counter(x), key=collections.Counter(x).get))
df1
# Out:
#                             0                   1
# 0    668f64fb8cc61c379809bfe8     task_4_k_wiping
# 1    668f64fb8cc61c379809bfff     task_4_k_wiping
# 2    668f64fb8cc61c379809c0c7     task_4_k_wiping
# 3    668f64fb8cc61c379809c0dd     task_4_k_wiping
# 4    668f64fb8cc61c379809c182    task_3_k_pouring
# ..                        ...                 ...
# 103  668f64fc8cc61c379809f366     task_4_k_wiping
# 104  668f64fc8cc61c379809f4ae     task_4_k_wiping
# 105  668f64fc8cc61c379809f4d3  task_8_w_hammering
# 106  668f64fc8cc61c379809f574     task_9_w_sawing
# 107  668f64fc8cc61c379809f585     task_9_w_sawing
#
# [108 rows x 2 columns]

# %%
df1[0] = df1[0].apply(lambda x: id_to_utterance[x])

# %%
sum(df1[0] == df1[1])/len(df1[0])
# Out:
# 0.28703703703703703

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(df1[0], df1[1])
# Out:
# array([[ 0,  0,  0, 12,  0,  0,  0,  0,  0],
#        [ 0,  0,  0, 12,  0,  0,  0,  0,  0],
#        [ 0,  0,  5,  0,  0,  0,  0,  7,  0],
#        [ 0,  0,  0, 12,  0,  0,  0,  0,  0],
#        [ 0,  0,  1, 11,  0,  0,  0,  0,  0],
#        [ 0,  0,  0, 12,  0,  0,  0,  0,  0],
#        [ 0,  0,  0, 12,  0,  0,  0,  0,  0],
#        [ 0,  0,  1,  8,  0,  0,  0,  3,  0],
#        [ 0,  0,  0,  1,  0,  0,  0,  0, 11]], dtype=int64)

# %%
(df1[0], df1[1])
# Out:
# 0.28703703703703703

# %%
df1[0].value_counts()
# Out:
# 0
# task_1_k_cooking               12
# task_2_k_cooking_with_bowls    12
# task_3_k_pouring               12
# task_4_k_wiping                12
# task_5_k_cereals               12
# task_6_w_hard_drive            12
# task_7_w_free_hard_drive       12
# task_8_w_hammering             12
# task_9_w_sawing                12
# Name: count, dtype: int64

# %%
df1[1].value_counts()
# Out:
# 1
# task_4_k_wiping       80
# task_9_w_sawing       11
# task_8_w_hammering    10
# task_3_k_pouring       7
# Name: count, dtype: int64

# %%
preds = []
trues = []
for i, (pred, true) in enumerate(zip(predicted_heads, true_labels)):
    predicted_head_str = entity_id_to_label[pred]
    preds.append(predicted_head_str)
    true_head_str = train_triples_factory.entity_id_to_label[true]
    trues.append(true_head_str)
    print(f"Prediction {i+1}: Predicted head = {predicted_head_str}, True head = {true_head_str}")
# Out:
# Prediction 1: Predicted head = task_9_w_sawing, True head = task_1_k_cooking
# Prediction 2: Predicted head = task_4_k_wiping, True head = task_1_k_cooking
# Prediction 3: Predicted head = task_8_w_hammering, True head = task_1_k_cooking
# Prediction 4: Predicted head = task_6_w_hard_drive, True head = task_1_k_cooking
# Prediction 5: Predicted head = task_7_w_free_hard_drive, True head = task_1_k_cooking
# Prediction 6: Predicted head = task_3_k_pouring, True head = task_1_k_cooking
# Prediction 7: Predicted head = task_9_w_sawing, True head = task_1_k_cooking
# Prediction 8: Predicted head = task_4_k_wiping, True head = task_1_k_cooking
# Prediction 9: Predicted head = task_5_k_cereals, True head = task_1_k_cooking
# Prediction 10: Predicted head = task_3_k_pouring, True head = task_1_k_cooking
# Prediction 11: Predicted head = task_4_k_wiping, True head = task_1_k_cooking
# Prediction 12: Predicted head = task_8_w_hammering, True head = task_1_k_cooking
# Prediction 13: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 14: Predicted head = task_7_w_free_hard_drive, True head = task_1_k_cooking
# Prediction 15: Predicted head = task_3_k_pouring, True head = task_1_k_cooking
# Prediction 16: Predicted head = task_4_k_wiping, True head = task_1_k_cooking
# Prediction 17: Predicted head = task_5_k_cereals, True head = task_1_k_cooking
# Prediction 18: Predicted head = task_3_k_pouring, True head = task_1_k_cooking
# Prediction 19: Predicted head = task_9_w_sawing, True head = task_1_k_cooking
# Prediction 20: Predicted head = task_4_k_wiping, True head = task_1_k_cooking
# Prediction 21: Predicted head = task_8_w_hammering, True head = task_1_k_cooking
# Prediction 22: Predicted head = task_6_w_hard_drive, True head = task_1_k_cooking
# Prediction 23: Predicted head = task_7_w_free_hard_drive, True head = task_1_k_cooking
# Prediction 24: Predicted head = task_3_k_pouring, True head = task_1_k_cooking
# Prediction 25: Predicted head = task_9_w_sawing, True head = task_1_k_cooking
# Prediction 26: Predicted head = task_4_k_wiping, True head = task_1_k_cooking
# Prediction 27: Predicted head = task_5_k_cereals, True head = task_1_k_cooking
# Prediction 28: Predicted head = task_3_k_pouring, True head = task_1_k_cooking
# Prediction 29: Predicted head = task_4_k_wiping, True head = task_1_k_cooking
# Prediction 30: Predicted head = task_8_w_hammering, True head = task_1_k_cooking
# Prediction 31: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 32: Predicted head = task_7_w_free_hard_drive, True head = task_1_k_cooking
# Prediction 33: Predicted head = task_3_k_pouring, True head = task_1_k_cooking
# Prediction 34: Predicted head = task_4_k_wiping, True head = task_1_k_cooking
# Prediction 35: Predicted head = task_5_k_cereals, True head = task_1_k_cooking
# Prediction 36: Predicted head = task_3_k_pouring, True head = task_1_k_cooking
# Prediction 37: Predicted head = task_9_w_sawing, True head = task_2_k_cooking_with_bowls
# Prediction 38: Predicted head = task_4_k_wiping, True head = task_2_k_cooking_with_bowls
# Prediction 39: Predicted head = task_8_w_hammering, True head = task_2_k_cooking_with_bowls
# Prediction 40: Predicted head = task_6_w_hard_drive, True head = task_2_k_cooking_with_bowls
# Prediction 41: Predicted head = task_7_w_free_hard_drive, True head = task_2_k_cooking_with_bowls
# Prediction 42: Predicted head = task_3_k_pouring, True head = task_2_k_cooking_with_bowls
# Prediction 43: Predicted head = task_9_w_sawing, True head = task_2_k_cooking_with_bowls
# Prediction 44: Predicted head = task_4_k_wiping, True head = task_2_k_cooking_with_bowls
# Prediction 45: Predicted head = task_5_k_cereals, True head = task_2_k_cooking_with_bowls
# Prediction 46: Predicted head = task_3_k_pouring, True head = task_2_k_cooking_with_bowls
# Prediction 47: Predicted head = task_4_k_wiping, True head = task_2_k_cooking_with_bowls
# Prediction 48: Predicted head = task_8_w_hammering, True head = task_2_k_cooking_with_bowls
# Prediction 49: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 50: Predicted head = task_7_w_free_hard_drive, True head = task_2_k_cooking_with_bowls
# Prediction 51: Predicted head = task_3_k_pouring, True head = task_2_k_cooking_with_bowls
# Prediction 52: Predicted head = task_4_k_wiping, True head = task_2_k_cooking_with_bowls
# Prediction 53: Predicted head = task_5_k_cereals, True head = task_2_k_cooking_with_bowls
# Prediction 54: Predicted head = task_3_k_pouring, True head = task_2_k_cooking_with_bowls
# Prediction 55: Predicted head = task_9_w_sawing, True head = task_2_k_cooking_with_bowls
# Prediction 56: Predicted head = task_4_k_wiping, True head = task_2_k_cooking_with_bowls
# Prediction 57: Predicted head = task_8_w_hammering, True head = task_2_k_cooking_with_bowls
# Prediction 58: Predicted head = task_6_w_hard_drive, True head = task_2_k_cooking_with_bowls
# Prediction 59: Predicted head = task_7_w_free_hard_drive, True head = task_2_k_cooking_with_bowls
# Prediction 60: Predicted head = task_3_k_pouring, True head = task_2_k_cooking_with_bowls
# Prediction 61: Predicted head = task_9_w_sawing, True head = task_2_k_cooking_with_bowls
# Prediction 62: Predicted head = task_4_k_wiping, True head = task_2_k_cooking_with_bowls
# Prediction 63: Predicted head = task_5_k_cereals, True head = task_2_k_cooking_with_bowls
# Prediction 64: Predicted head = task_3_k_pouring, True head = task_2_k_cooking_with_bowls
# Prediction 65: Predicted head = task_4_k_wiping, True head = task_2_k_cooking_with_bowls
# Prediction 66: Predicted head = task_8_w_hammering, True head = task_2_k_cooking_with_bowls
# Prediction 67: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 68: Predicted head = task_7_w_free_hard_drive, True head = task_2_k_cooking_with_bowls
# Prediction 69: Predicted head = task_3_k_pouring, True head = task_2_k_cooking_with_bowls
# Prediction 70: Predicted head = task_4_k_wiping, True head = task_2_k_cooking_with_bowls
# Prediction 71: Predicted head = task_5_k_cereals, True head = task_2_k_cooking_with_bowls
# Prediction 72: Predicted head = task_3_k_pouring, True head = task_2_k_cooking_with_bowls
# Prediction 73: Predicted head = task_9_w_sawing, True head = task_3_k_pouring
# Prediction 74: Predicted head = task_4_k_wiping, True head = task_3_k_pouring
# Prediction 75: Predicted head = task_8_w_hammering, True head = task_3_k_pouring
# Prediction 76: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 77: Predicted head = task_7_w_free_hard_drive, True head = task_3_k_pouring
# Prediction 78: Predicted head = task_3_k_pouring, True head = task_3_k_pouring
# Prediction 79: Predicted head = task_9_w_sawing, True head = task_3_k_pouring
# Prediction 80: Predicted head = task_4_k_wiping, True head = task_3_k_pouring
# Prediction 81: Predicted head = task_5_k_cereals, True head = task_3_k_pouring
# Prediction 82: Predicted head = task_8_w_hammering, True head = task_3_k_pouring
# Prediction 83: Predicted head = task_3_k_pouring, True head = task_3_k_pouring
# Prediction 84: Predicted head = task_7_w_free_hard_drive, True head = task_3_k_pouring
# Prediction 85: Predicted head = task_3_k_pouring, True head = task_3_k_pouring
# Prediction 86: Predicted head = task_9_w_sawing, True head = task_3_k_pouring
# Prediction 87: Predicted head = task_4_k_wiping, True head = task_3_k_pouring
# Prediction 88: Predicted head = task_8_w_hammering, True head = task_3_k_pouring
# Prediction 89: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 90: Predicted head = task_7_w_free_hard_drive, True head = task_3_k_pouring
# Prediction 91: Predicted head = task_3_k_pouring, True head = task_3_k_pouring
# Prediction 92: Predicted head = task_9_w_sawing, True head = task_3_k_pouring
# Prediction 93: Predicted head = task_4_k_wiping, True head = task_3_k_pouring
# Prediction 94: Predicted head = task_8_w_hammering, True head = task_3_k_pouring
# Prediction 95: Predicted head = task_5_k_cereals, True head = task_3_k_pouring
# Prediction 96: Predicted head = task_8_w_hammering, True head = task_3_k_pouring
# Prediction 97: Predicted head = task_3_k_pouring, True head = task_3_k_pouring
# Prediction 98: Predicted head = task_7_w_free_hard_drive, True head = task_3_k_pouring
# Prediction 99: Predicted head = task_3_k_pouring, True head = task_3_k_pouring
# Prediction 100: Predicted head = task_9_w_sawing, True head = task_4_k_wiping
# Prediction 101: Predicted head = task_4_k_wiping, True head = task_4_k_wiping
# Prediction 102: Predicted head = task_4_k_wiping, True head = task_4_k_wiping
# Prediction 103: Predicted head = task_3_k_pouring, True head = task_4_k_wiping
# Prediction 104: Predicted head = task_9_w_sawing, True head = task_4_k_wiping
# Prediction 105: Predicted head = task_4_k_wiping, True head = task_4_k_wiping
# Prediction 106: Predicted head = task_8_w_hammering, True head = task_4_k_wiping
# Prediction 107: Predicted head = task_5_k_cereals, True head = task_4_k_wiping
# Prediction 108: Predicted head = task_7_w_free_hard_drive, True head = task_4_k_wiping
# Prediction 109: Predicted head = task_3_k_pouring, True head = task_4_k_wiping
# Prediction 110: Predicted head = task_4_k_wiping, True head = task_4_k_wiping
# Prediction 111: Predicted head = task_8_w_hammering, True head = task_4_k_wiping
# Prediction 112: Predicted head = task_5_k_cereals, True head = task_4_k_wiping
# Prediction 113: Predicted head = task_7_w_free_hard_drive, True head = task_4_k_wiping
# Prediction 114: Predicted head = task_3_k_pouring, True head = task_4_k_wiping
# Prediction 115: Predicted head = task_9_w_sawing, True head = task_4_k_wiping
# Prediction 116: Predicted head = task_4_k_wiping, True head = task_4_k_wiping
# Prediction 117: Predicted head = task_4_k_wiping, True head = task_4_k_wiping
# Prediction 118: Predicted head = task_3_k_pouring, True head = task_4_k_wiping
# Prediction 119: Predicted head = task_9_w_sawing, True head = task_4_k_wiping
# Prediction 120: Predicted head = task_4_k_wiping, True head = task_4_k_wiping
# Prediction 121: Predicted head = task_8_w_hammering, True head = task_4_k_wiping
# Prediction 122: Predicted head = task_5_k_cereals, True head = task_4_k_wiping
# Prediction 123: Predicted head = task_7_w_free_hard_drive, True head = task_4_k_wiping
# Prediction 124: Predicted head = task_3_k_pouring, True head = task_4_k_wiping
# Prediction 125: Predicted head = task_4_k_wiping, True head = task_4_k_wiping
# Prediction 126: Predicted head = task_8_w_hammering, True head = task_4_k_wiping
# Prediction 127: Predicted head = task_5_k_cereals, True head = task_4_k_wiping
# Prediction 128: Predicted head = task_7_w_free_hard_drive, True head = task_4_k_wiping
# Prediction 129: Predicted head = task_3_k_pouring, True head = task_4_k_wiping
# Prediction 130: Predicted head = task_9_w_sawing, True head = task_5_k_cereals
# Prediction 131: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 132: Predicted head = task_8_w_hammering, True head = task_5_k_cereals
# Prediction 133: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 134: Predicted head = task_7_w_free_hard_drive, True head = task_5_k_cereals
# Prediction 135: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 136: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 137: Predicted head = task_8_w_hammering, True head = task_5_k_cereals
# Prediction 138: Predicted head = task_5_k_cereals, True head = task_5_k_cereals
# Prediction 139: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 140: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 141: Predicted head = task_8_w_hammering, True head = task_5_k_cereals
# Prediction 142: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 143: Predicted head = task_7_w_free_hard_drive, True head = task_5_k_cereals
# Prediction 144: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 145: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 146: Predicted head = task_8_w_hammering, True head = task_5_k_cereals
# Prediction 147: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 148: Predicted head = task_7_w_free_hard_drive, True head = task_5_k_cereals
# Prediction 149: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 150: Predicted head = task_9_w_sawing, True head = task_5_k_cereals
# Prediction 151: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 152: Predicted head = task_5_k_cereals, True head = task_5_k_cereals
# Prediction 153: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 154: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 155: Predicted head = task_5_k_cereals, True head = task_5_k_cereals
# Prediction 156: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 157: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 158: Predicted head = task_8_w_hammering, True head = task_5_k_cereals
# Prediction 159: Predicted head = task_5_k_cereals, True head = task_5_k_cereals
# Prediction 160: Predicted head = task_7_w_free_hard_drive, True head = task_5_k_cereals
# Prediction 161: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 162: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 163: Predicted head = task_5_k_cereals, True head = task_5_k_cereals
# Prediction 164: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 165: Predicted head = task_9_w_sawing, True head = task_5_k_cereals
# Prediction 166: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 167: Predicted head = task_8_w_hammering, True head = task_5_k_cereals
# Prediction 168: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 169: Predicted head = task_7_w_free_hard_drive, True head = task_5_k_cereals
# Prediction 170: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 171: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 172: Predicted head = task_8_w_hammering, True head = task_5_k_cereals
# Prediction 173: Predicted head = task_5_k_cereals, True head = task_5_k_cereals
# Prediction 174: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 175: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 176: Predicted head = task_8_w_hammering, True head = task_5_k_cereals
# Prediction 177: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 178: Predicted head = task_7_w_free_hard_drive, True head = task_5_k_cereals
# Prediction 179: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 180: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 181: Predicted head = task_8_w_hammering, True head = task_5_k_cereals
# Prediction 182: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 183: Predicted head = task_7_w_free_hard_drive, True head = task_5_k_cereals
# Prediction 184: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 185: Predicted head = task_9_w_sawing, True head = task_5_k_cereals
# Prediction 186: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 187: Predicted head = task_5_k_cereals, True head = task_5_k_cereals
# Prediction 188: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 189: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 190: Predicted head = task_5_k_cereals, True head = task_5_k_cereals
# Prediction 191: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 192: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 193: Predicted head = task_8_w_hammering, True head = task_5_k_cereals
# Prediction 194: Predicted head = task_5_k_cereals, True head = task_5_k_cereals
# Prediction 195: Predicted head = task_7_w_free_hard_drive, True head = task_5_k_cereals
# Prediction 196: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 197: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 198: Predicted head = task_5_k_cereals, True head = task_5_k_cereals
# Prediction 199: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 200: Predicted head = task_9_w_sawing, True head = task_6_w_hard_drive
# Prediction 201: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 202: Predicted head = task_8_w_hammering, True head = task_6_w_hard_drive
# Prediction 203: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 204: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 205: Predicted head = task_9_w_sawing, True head = task_6_w_hard_drive
# Prediction 206: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 207: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 208: Predicted head = task_7_w_free_hard_drive, True head = task_6_w_hard_drive
# Prediction 209: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 210: Predicted head = task_9_w_sawing, True head = task_6_w_hard_drive
# Prediction 211: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 212: Predicted head = task_5_k_cereals, True head = task_6_w_hard_drive
# Prediction 213: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 214: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 215: Predicted head = task_5_k_cereals, True head = task_6_w_hard_drive
# Prediction 216: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 217: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 218: Predicted head = task_8_w_hammering, True head = task_6_w_hard_drive
# Prediction 219: Predicted head = task_7_w_free_hard_drive, True head = task_6_w_hard_drive
# Prediction 220: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 221: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 222: Predicted head = task_5_k_cereals, True head = task_6_w_hard_drive
# Prediction 223: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 224: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 225: Predicted head = task_8_w_hammering, True head = task_6_w_hard_drive
# Prediction 226: Predicted head = task_7_w_free_hard_drive, True head = task_6_w_hard_drive
# Prediction 227: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 228: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 229: Predicted head = task_5_k_cereals, True head = task_6_w_hard_drive
# Prediction 230: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 231: Predicted head = task_9_w_sawing, True head = task_6_w_hard_drive
# Prediction 232: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 233: Predicted head = task_8_w_hammering, True head = task_6_w_hard_drive
# Prediction 234: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 235: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 236: Predicted head = task_9_w_sawing, True head = task_6_w_hard_drive
# Prediction 237: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 238: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 239: Predicted head = task_7_w_free_hard_drive, True head = task_6_w_hard_drive
# Prediction 240: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 241: Predicted head = task_9_w_sawing, True head = task_6_w_hard_drive
# Prediction 242: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 243: Predicted head = task_5_k_cereals, True head = task_6_w_hard_drive
# Prediction 244: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 245: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 246: Predicted head = task_5_k_cereals, True head = task_6_w_hard_drive
# Prediction 247: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 248: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 249: Predicted head = task_8_w_hammering, True head = task_6_w_hard_drive
# Prediction 250: Predicted head = task_7_w_free_hard_drive, True head = task_6_w_hard_drive
# Prediction 251: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 252: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 253: Predicted head = task_5_k_cereals, True head = task_6_w_hard_drive
# Prediction 254: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 255: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 256: Predicted head = task_8_w_hammering, True head = task_6_w_hard_drive
# Prediction 257: Predicted head = task_7_w_free_hard_drive, True head = task_6_w_hard_drive
# Prediction 258: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 259: Predicted head = task_9_w_sawing, True head = task_7_w_free_hard_drive
# Prediction 260: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 261: Predicted head = task_8_w_hammering, True head = task_7_w_free_hard_drive
# Prediction 262: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 263: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 264: Predicted head = task_8_w_hammering, True head = task_7_w_free_hard_drive
# Prediction 265: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 266: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 267: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 268: Predicted head = task_8_w_hammering, True head = task_7_w_free_hard_drive
# Prediction 269: Predicted head = task_7_w_free_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 270: Predicted head = task_7_w_free_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 271: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 272: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 273: Predicted head = task_7_w_free_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 274: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 275: Predicted head = task_9_w_sawing, True head = task_7_w_free_hard_drive
# Prediction 276: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 277: Predicted head = task_5_k_cereals, True head = task_7_w_free_hard_drive
# Prediction 278: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 279: Predicted head = task_9_w_sawing, True head = task_7_w_free_hard_drive
# Prediction 280: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 281: Predicted head = task_8_w_hammering, True head = task_7_w_free_hard_drive
# Prediction 282: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 283: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 284: Predicted head = task_8_w_hammering, True head = task_7_w_free_hard_drive
# Prediction 285: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 286: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 287: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 288: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 289: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 290: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 291: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 292: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 293: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 294: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 295: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 296: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 297: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 298: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 299: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 300: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 301: Predicted head = task_7_w_free_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 302: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 303: Predicted head = task_9_w_sawing, True head = task_7_w_free_hard_drive
# Prediction 304: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 305: Predicted head = task_5_k_cereals, True head = task_7_w_free_hard_drive
# Prediction 306: Predicted head = task_7_w_free_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 307: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 308: Predicted head = task_9_w_sawing, True head = task_8_w_hammering
# Prediction 309: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 310: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 311: Predicted head = task_9_w_sawing, True head = task_8_w_hammering
# Prediction 312: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 313: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 314: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 315: Predicted head = task_9_w_sawing, True head = task_8_w_hammering
# Prediction 316: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 317: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 318: Predicted head = task_7_w_free_hard_drive, True head = task_8_w_hammering
# Prediction 319: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 320: Predicted head = task_9_w_sawing, True head = task_8_w_hammering
# Prediction 321: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 322: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 323: Predicted head = task_7_w_free_hard_drive, True head = task_8_w_hammering
# Prediction 324: Predicted head = task_5_k_cereals, True head = task_8_w_hammering
# Prediction 325: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 326: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 327: Predicted head = task_5_k_cereals, True head = task_8_w_hammering
# Prediction 328: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 329: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 330: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 331: Predicted head = task_7_w_free_hard_drive, True head = task_8_w_hammering
# Prediction 332: Predicted head = task_5_k_cereals, True head = task_8_w_hammering
# Prediction 333: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 334: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 335: Predicted head = task_5_k_cereals, True head = task_8_w_hammering
# Prediction 336: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 337: Predicted head = task_9_w_sawing, True head = task_8_w_hammering
# Prediction 338: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 339: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 340: Predicted head = task_9_w_sawing, True head = task_8_w_hammering
# Prediction 341: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 342: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 343: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 344: Predicted head = task_9_w_sawing, True head = task_8_w_hammering
# Prediction 345: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 346: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 347: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 348: Predicted head = task_9_w_sawing, True head = task_8_w_hammering
# Prediction 349: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 350: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 351: Predicted head = task_7_w_free_hard_drive, True head = task_8_w_hammering
# Prediction 352: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 353: Predicted head = task_9_w_sawing, True head = task_8_w_hammering
# Prediction 354: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 355: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 356: Predicted head = task_7_w_free_hard_drive, True head = task_8_w_hammering
# Prediction 357: Predicted head = task_5_k_cereals, True head = task_8_w_hammering
# Prediction 358: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 359: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 360: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 361: Predicted head = task_7_w_free_hard_drive, True head = task_8_w_hammering
# Prediction 362: Predicted head = task_5_k_cereals, True head = task_8_w_hammering
# Prediction 363: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 364: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 365: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 366: Predicted head = task_7_w_free_hard_drive, True head = task_8_w_hammering
# Prediction 367: Predicted head = task_5_k_cereals, True head = task_8_w_hammering
# Prediction 368: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 369: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 370: Predicted head = task_5_k_cereals, True head = task_8_w_hammering
# Prediction 371: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 372: Predicted head = task_9_w_sawing, True head = task_9_w_sawing
# Prediction 373: Predicted head = task_4_k_wiping, True head = task_9_w_sawing
# Prediction 374: Predicted head = task_8_w_hammering, True head = task_9_w_sawing
# Prediction 375: Predicted head = task_9_w_sawing, True head = task_9_w_sawing
# Prediction 376: Predicted head = task_7_w_free_hard_drive, True head = task_9_w_sawing
# Prediction 377: Predicted head = task_3_k_pouring, True head = task_9_w_sawing
# Prediction 378: Predicted head = task_9_w_sawing, True head = task_9_w_sawing
# Prediction 379: Predicted head = task_4_k_wiping, True head = task_9_w_sawing
# Prediction 380: Predicted head = task_5_k_cereals, True head = task_9_w_sawing
# Prediction 381: Predicted head = task_3_k_pouring, True head = task_9_w_sawing
# Prediction 382: Predicted head = task_4_k_wiping, True head = task_9_w_sawing
# Prediction 383: Predicted head = task_5_k_cereals, True head = task_9_w_sawing
# Prediction 384: Predicted head = task_3_k_pouring, True head = task_9_w_sawing
# Prediction 385: Predicted head = task_9_w_sawing, True head = task_9_w_sawing
# Prediction 386: Predicted head = task_4_k_wiping, True head = task_9_w_sawing
# Prediction 387: Predicted head = task_8_w_hammering, True head = task_9_w_sawing
# Prediction 388: Predicted head = task_9_w_sawing, True head = task_9_w_sawing
# Prediction 389: Predicted head = task_7_w_free_hard_drive, True head = task_9_w_sawing
# Prediction 390: Predicted head = task_3_k_pouring, True head = task_9_w_sawing
# Prediction 391: Predicted head = task_4_k_wiping, True head = task_9_w_sawing
# Prediction 392: Predicted head = task_8_w_hammering, True head = task_9_w_sawing
# Prediction 393: Predicted head = task_7_w_free_hard_drive, True head = task_9_w_sawing
# Prediction 394: Predicted head = task_3_k_pouring, True head = task_9_w_sawing
# Prediction 395: Predicted head = task_9_w_sawing, True head = task_9_w_sawing
# Prediction 396: Predicted head = task_4_k_wiping, True head = task_9_w_sawing
# Prediction 397: Predicted head = task_5_k_cereals, True head = task_9_w_sawing
# Prediction 398: Predicted head = task_8_w_hammering, True head = task_9_w_sawing
# Prediction 399: Predicted head = task_7_w_free_hard_drive, True head = task_9_w_sawing
# Prediction 400: Predicted head = task_3_k_pouring, True head = task_9_w_sawing
# Prediction 401: Predicted head = task_9_w_sawing, True head = task_1_k_cooking
# Prediction 402: Predicted head = task_4_k_wiping, True head = task_1_k_cooking
# Prediction 403: Predicted head = task_8_w_hammering, True head = task_1_k_cooking
# Prediction 404: Predicted head = task_6_w_hard_drive, True head = task_1_k_cooking
# Prediction 405: Predicted head = task_7_w_free_hard_drive, True head = task_1_k_cooking
# Prediction 406: Predicted head = task_3_k_pouring, True head = task_1_k_cooking
# Prediction 407: Predicted head = task_9_w_sawing, True head = task_1_k_cooking
# Prediction 408: Predicted head = task_4_k_wiping, True head = task_1_k_cooking
# Prediction 409: Predicted head = task_5_k_cereals, True head = task_1_k_cooking
# Prediction 410: Predicted head = task_3_k_pouring, True head = task_1_k_cooking
# Prediction 411: Predicted head = task_4_k_wiping, True head = task_1_k_cooking
# Prediction 412: Predicted head = task_8_w_hammering, True head = task_1_k_cooking
# Prediction 413: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 414: Predicted head = task_7_w_free_hard_drive, True head = task_1_k_cooking
# Prediction 415: Predicted head = task_3_k_pouring, True head = task_1_k_cooking
# Prediction 416: Predicted head = task_4_k_wiping, True head = task_1_k_cooking
# Prediction 417: Predicted head = task_5_k_cereals, True head = task_1_k_cooking
# Prediction 418: Predicted head = task_3_k_pouring, True head = task_1_k_cooking
# Prediction 419: Predicted head = task_9_w_sawing, True head = task_1_k_cooking
# Prediction 420: Predicted head = task_4_k_wiping, True head = task_1_k_cooking
# Prediction 421: Predicted head = task_8_w_hammering, True head = task_1_k_cooking
# Prediction 422: Predicted head = task_6_w_hard_drive, True head = task_1_k_cooking
# Prediction 423: Predicted head = task_7_w_free_hard_drive, True head = task_1_k_cooking
# Prediction 424: Predicted head = task_3_k_pouring, True head = task_1_k_cooking
# Prediction 425: Predicted head = task_9_w_sawing, True head = task_1_k_cooking
# Prediction 426: Predicted head = task_4_k_wiping, True head = task_1_k_cooking
# Prediction 427: Predicted head = task_5_k_cereals, True head = task_1_k_cooking
# Prediction 428: Predicted head = task_3_k_pouring, True head = task_1_k_cooking
# Prediction 429: Predicted head = task_4_k_wiping, True head = task_1_k_cooking
# Prediction 430: Predicted head = task_8_w_hammering, True head = task_1_k_cooking
# Prediction 431: Predicted head = task_2_k_cooking_with_bowls, True head = task_1_k_cooking
# Prediction 432: Predicted head = task_7_w_free_hard_drive, True head = task_1_k_cooking
# Prediction 433: Predicted head = task_3_k_pouring, True head = task_1_k_cooking
# Prediction 434: Predicted head = task_4_k_wiping, True head = task_1_k_cooking
# Prediction 435: Predicted head = task_5_k_cereals, True head = task_1_k_cooking
# Prediction 436: Predicted head = task_3_k_pouring, True head = task_1_k_cooking
# Prediction 437: Predicted head = task_9_w_sawing, True head = task_2_k_cooking_with_bowls
# Prediction 438: Predicted head = task_4_k_wiping, True head = task_2_k_cooking_with_bowls
# Prediction 439: Predicted head = task_8_w_hammering, True head = task_2_k_cooking_with_bowls
# Prediction 440: Predicted head = task_6_w_hard_drive, True head = task_2_k_cooking_with_bowls
# Prediction 441: Predicted head = task_7_w_free_hard_drive, True head = task_2_k_cooking_with_bowls
# Prediction 442: Predicted head = task_3_k_pouring, True head = task_2_k_cooking_with_bowls
# Prediction 443: Predicted head = task_9_w_sawing, True head = task_2_k_cooking_with_bowls
# Prediction 444: Predicted head = task_4_k_wiping, True head = task_2_k_cooking_with_bowls
# Prediction 445: Predicted head = task_5_k_cereals, True head = task_2_k_cooking_with_bowls
# Prediction 446: Predicted head = task_3_k_pouring, True head = task_2_k_cooking_with_bowls
# Prediction 447: Predicted head = task_4_k_wiping, True head = task_2_k_cooking_with_bowls
# Prediction 448: Predicted head = task_8_w_hammering, True head = task_2_k_cooking_with_bowls
# Prediction 449: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 450: Predicted head = task_7_w_free_hard_drive, True head = task_2_k_cooking_with_bowls
# Prediction 451: Predicted head = task_3_k_pouring, True head = task_2_k_cooking_with_bowls
# Prediction 452: Predicted head = task_4_k_wiping, True head = task_2_k_cooking_with_bowls
# Prediction 453: Predicted head = task_5_k_cereals, True head = task_2_k_cooking_with_bowls
# Prediction 454: Predicted head = task_3_k_pouring, True head = task_2_k_cooking_with_bowls
# Prediction 455: Predicted head = task_9_w_sawing, True head = task_2_k_cooking_with_bowls
# Prediction 456: Predicted head = task_4_k_wiping, True head = task_2_k_cooking_with_bowls
# Prediction 457: Predicted head = task_8_w_hammering, True head = task_2_k_cooking_with_bowls
# Prediction 458: Predicted head = task_6_w_hard_drive, True head = task_2_k_cooking_with_bowls
# Prediction 459: Predicted head = task_7_w_free_hard_drive, True head = task_2_k_cooking_with_bowls
# Prediction 460: Predicted head = task_3_k_pouring, True head = task_2_k_cooking_with_bowls
# Prediction 461: Predicted head = task_9_w_sawing, True head = task_2_k_cooking_with_bowls
# Prediction 462: Predicted head = task_4_k_wiping, True head = task_2_k_cooking_with_bowls
# Prediction 463: Predicted head = task_5_k_cereals, True head = task_2_k_cooking_with_bowls
# Prediction 464: Predicted head = task_3_k_pouring, True head = task_2_k_cooking_with_bowls
# Prediction 465: Predicted head = task_4_k_wiping, True head = task_2_k_cooking_with_bowls
# Prediction 466: Predicted head = task_8_w_hammering, True head = task_2_k_cooking_with_bowls
# Prediction 467: Predicted head = task_2_k_cooking_with_bowls, True head = task_2_k_cooking_with_bowls
# Prediction 468: Predicted head = task_7_w_free_hard_drive, True head = task_2_k_cooking_with_bowls
# Prediction 469: Predicted head = task_3_k_pouring, True head = task_2_k_cooking_with_bowls
# Prediction 470: Predicted head = task_4_k_wiping, True head = task_2_k_cooking_with_bowls
# Prediction 471: Predicted head = task_5_k_cereals, True head = task_2_k_cooking_with_bowls
# Prediction 472: Predicted head = task_3_k_pouring, True head = task_2_k_cooking_with_bowls
# Prediction 473: Predicted head = task_9_w_sawing, True head = task_3_k_pouring
# Prediction 474: Predicted head = task_4_k_wiping, True head = task_3_k_pouring
# Prediction 475: Predicted head = task_8_w_hammering, True head = task_3_k_pouring
# Prediction 476: Predicted head = task_5_k_cereals, True head = task_3_k_pouring
# Prediction 477: Predicted head = task_8_w_hammering, True head = task_3_k_pouring
# Prediction 478: Predicted head = task_3_k_pouring, True head = task_3_k_pouring
# Prediction 479: Predicted head = task_7_w_free_hard_drive, True head = task_3_k_pouring
# Prediction 480: Predicted head = task_3_k_pouring, True head = task_3_k_pouring
# Prediction 481: Predicted head = task_9_w_sawing, True head = task_3_k_pouring
# Prediction 482: Predicted head = task_4_k_wiping, True head = task_3_k_pouring
# Prediction 483: Predicted head = task_8_w_hammering, True head = task_3_k_pouring
# Prediction 484: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 485: Predicted head = task_7_w_free_hard_drive, True head = task_3_k_pouring
# Prediction 486: Predicted head = task_3_k_pouring, True head = task_3_k_pouring
# Prediction 487: Predicted head = task_9_w_sawing, True head = task_3_k_pouring
# Prediction 488: Predicted head = task_4_k_wiping, True head = task_3_k_pouring
# Prediction 489: Predicted head = task_8_w_hammering, True head = task_3_k_pouring
# Prediction 490: Predicted head = task_5_k_cereals, True head = task_3_k_pouring
# Prediction 491: Predicted head = task_8_w_hammering, True head = task_3_k_pouring
# Prediction 492: Predicted head = task_3_k_pouring, True head = task_3_k_pouring
# Prediction 493: Predicted head = task_7_w_free_hard_drive, True head = task_3_k_pouring
# Prediction 494: Predicted head = task_3_k_pouring, True head = task_3_k_pouring
# Prediction 495: Predicted head = task_9_w_sawing, True head = task_3_k_pouring
# Prediction 496: Predicted head = task_4_k_wiping, True head = task_3_k_pouring
# Prediction 497: Predicted head = task_8_w_hammering, True head = task_3_k_pouring
# Prediction 498: Predicted head = task_2_k_cooking_with_bowls, True head = task_3_k_pouring
# Prediction 499: Predicted head = task_7_w_free_hard_drive, True head = task_3_k_pouring
# Prediction 500: Predicted head = task_3_k_pouring, True head = task_3_k_pouring
# Prediction 501: Predicted head = task_9_w_sawing, True head = task_4_k_wiping
# Prediction 502: Predicted head = task_4_k_wiping, True head = task_4_k_wiping
# Prediction 503: Predicted head = task_4_k_wiping, True head = task_4_k_wiping
# Prediction 504: Predicted head = task_3_k_pouring, True head = task_4_k_wiping
# Prediction 505: Predicted head = task_9_w_sawing, True head = task_4_k_wiping
# Prediction 506: Predicted head = task_4_k_wiping, True head = task_4_k_wiping
# Prediction 507: Predicted head = task_4_k_wiping, True head = task_4_k_wiping
# Prediction 508: Predicted head = task_3_k_pouring, True head = task_4_k_wiping
# Prediction 509: Predicted head = task_9_w_sawing, True head = task_4_k_wiping
# Prediction 510: Predicted head = task_4_k_wiping, True head = task_4_k_wiping
# Prediction 511: Predicted head = task_8_w_hammering, True head = task_4_k_wiping
# Prediction 512: Predicted head = task_5_k_cereals, True head = task_4_k_wiping
# Prediction 513: Predicted head = task_7_w_free_hard_drive, True head = task_4_k_wiping
# Prediction 514: Predicted head = task_3_k_pouring, True head = task_4_k_wiping
# Prediction 515: Predicted head = task_4_k_wiping, True head = task_4_k_wiping
# Prediction 516: Predicted head = task_8_w_hammering, True head = task_4_k_wiping
# Prediction 517: Predicted head = task_5_k_cereals, True head = task_4_k_wiping
# Prediction 518: Predicted head = task_7_w_free_hard_drive, True head = task_4_k_wiping
# Prediction 519: Predicted head = task_3_k_pouring, True head = task_4_k_wiping
# Prediction 520: Predicted head = task_9_w_sawing, True head = task_5_k_cereals
# Prediction 521: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 522: Predicted head = task_8_w_hammering, True head = task_5_k_cereals
# Prediction 523: Predicted head = task_5_k_cereals, True head = task_5_k_cereals
# Prediction 524: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 525: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 526: Predicted head = task_8_w_hammering, True head = task_5_k_cereals
# Prediction 527: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 528: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 529: Predicted head = task_7_w_free_hard_drive, True head = task_5_k_cereals
# Prediction 530: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 531: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 532: Predicted head = task_5_k_cereals, True head = task_5_k_cereals
# Prediction 533: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 534: Predicted head = task_9_w_sawing, True head = task_5_k_cereals
# Prediction 535: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 536: Predicted head = task_8_w_hammering, True head = task_5_k_cereals
# Prediction 537: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 538: Predicted head = task_7_w_free_hard_drive, True head = task_5_k_cereals
# Prediction 539: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 540: Predicted head = task_9_w_sawing, True head = task_5_k_cereals
# Prediction 541: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 542: Predicted head = task_5_k_cereals, True head = task_5_k_cereals
# Prediction 543: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 544: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 545: Predicted head = task_8_w_hammering, True head = task_5_k_cereals
# Prediction 546: Predicted head = task_5_k_cereals, True head = task_5_k_cereals
# Prediction 547: Predicted head = task_7_w_free_hard_drive, True head = task_5_k_cereals
# Prediction 548: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 549: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 550: Predicted head = task_8_w_hammering, True head = task_5_k_cereals
# Prediction 551: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 552: Predicted head = task_7_w_free_hard_drive, True head = task_5_k_cereals
# Prediction 553: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 554: Predicted head = task_9_w_sawing, True head = task_5_k_cereals
# Prediction 555: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 556: Predicted head = task_8_w_hammering, True head = task_5_k_cereals
# Prediction 557: Predicted head = task_5_k_cereals, True head = task_5_k_cereals
# Prediction 558: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 559: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 560: Predicted head = task_8_w_hammering, True head = task_5_k_cereals
# Prediction 561: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 562: Predicted head = task_7_w_free_hard_drive, True head = task_5_k_cereals
# Prediction 563: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 564: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 565: Predicted head = task_5_k_cereals, True head = task_5_k_cereals
# Prediction 566: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 567: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 568: Predicted head = task_8_w_hammering, True head = task_5_k_cereals
# Prediction 569: Predicted head = task_2_k_cooking_with_bowls, True head = task_5_k_cereals
# Prediction 570: Predicted head = task_7_w_free_hard_drive, True head = task_5_k_cereals
# Prediction 571: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 572: Predicted head = task_9_w_sawing, True head = task_5_k_cereals
# Prediction 573: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 574: Predicted head = task_5_k_cereals, True head = task_5_k_cereals
# ...
# Prediction 2156: Predicted head = task_7_w_free_hard_drive, True head = task_5_k_cereals
# Prediction 2157: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 2158: Predicted head = task_4_k_wiping, True head = task_5_k_cereals
# Prediction 2159: Predicted head = task_5_k_cereals, True head = task_5_k_cereals
# Prediction 2160: Predicted head = task_3_k_pouring, True head = task_5_k_cereals
# Prediction 2161: Predicted head = task_9_w_sawing, True head = task_6_w_hard_drive
# Prediction 2162: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 2163: Predicted head = task_8_w_hammering, True head = task_6_w_hard_drive
# Prediction 2164: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 2165: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 2166: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 2167: Predicted head = task_8_w_hammering, True head = task_6_w_hard_drive
# Prediction 2168: Predicted head = task_7_w_free_hard_drive, True head = task_6_w_hard_drive
# Prediction 2169: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 2170: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 2171: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 2172: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 2173: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 2174: Predicted head = task_8_w_hammering, True head = task_6_w_hard_drive
# Prediction 2175: Predicted head = task_7_w_free_hard_drive, True head = task_6_w_hard_drive
# Prediction 2176: Predicted head = task_7_w_free_hard_drive, True head = task_6_w_hard_drive
# Prediction 2177: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 2178: Predicted head = task_9_w_sawing, True head = task_6_w_hard_drive
# Prediction 2179: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 2180: Predicted head = task_5_k_cereals, True head = task_6_w_hard_drive
# Prediction 2181: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 2182: Predicted head = task_9_w_sawing, True head = task_6_w_hard_drive
# Prediction 2183: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 2184: Predicted head = task_8_w_hammering, True head = task_6_w_hard_drive
# Prediction 2185: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 2186: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 2187: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 2188: Predicted head = task_8_w_hammering, True head = task_6_w_hard_drive
# Prediction 2189: Predicted head = task_7_w_free_hard_drive, True head = task_6_w_hard_drive
# Prediction 2190: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 2191: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 2192: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 2193: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 2194: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 2195: Predicted head = task_8_w_hammering, True head = task_6_w_hard_drive
# Prediction 2196: Predicted head = task_7_w_free_hard_drive, True head = task_6_w_hard_drive
# Prediction 2197: Predicted head = task_7_w_free_hard_drive, True head = task_6_w_hard_drive
# Prediction 2198: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 2199: Predicted head = task_9_w_sawing, True head = task_6_w_hard_drive
# Prediction 2200: Predicted head = task_4_k_wiping, True head = task_6_w_hard_drive
# Prediction 2201: Predicted head = task_5_k_cereals, True head = task_6_w_hard_drive
# Prediction 2202: Predicted head = task_3_k_pouring, True head = task_6_w_hard_drive
# Prediction 2203: Predicted head = task_9_w_sawing, True head = task_7_w_free_hard_drive
# Prediction 2204: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 2205: Predicted head = task_8_w_hammering, True head = task_7_w_free_hard_drive
# Prediction 2206: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 2207: Predicted head = task_8_w_hammering, True head = task_7_w_free_hard_drive
# Prediction 2208: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 2209: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 2210: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 2211: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 2212: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 2213: Predicted head = task_8_w_hammering, True head = task_7_w_free_hard_drive
# Prediction 2214: Predicted head = task_7_w_free_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 2215: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 2216: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 2217: Predicted head = task_5_k_cereals, True head = task_7_w_free_hard_drive
# Prediction 2218: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 2219: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 2220: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 2221: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 2222: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 2223: Predicted head = task_8_w_hammering, True head = task_7_w_free_hard_drive
# Prediction 2224: Predicted head = task_7_w_free_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 2225: Predicted head = task_7_w_free_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 2226: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 2227: Predicted head = task_9_w_sawing, True head = task_7_w_free_hard_drive
# Prediction 2228: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 2229: Predicted head = task_8_w_hammering, True head = task_7_w_free_hard_drive
# Prediction 2230: Predicted head = task_5_k_cereals, True head = task_7_w_free_hard_drive
# Prediction 2231: Predicted head = task_7_w_free_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 2232: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 2233: Predicted head = task_9_w_sawing, True head = task_7_w_free_hard_drive
# Prediction 2234: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 2235: Predicted head = task_8_w_hammering, True head = task_7_w_free_hard_drive
# Prediction 2236: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 2237: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 2238: Predicted head = task_8_w_hammering, True head = task_7_w_free_hard_drive
# Prediction 2239: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 2240: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 2241: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 2242: Predicted head = task_8_w_hammering, True head = task_7_w_free_hard_drive
# Prediction 2243: Predicted head = task_7_w_free_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 2244: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 2245: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 2246: Predicted head = task_5_k_cereals, True head = task_7_w_free_hard_drive
# Prediction 2247: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 2248: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 2249: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 2250: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 2251: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 2252: Predicted head = task_8_w_hammering, True head = task_7_w_free_hard_drive
# Prediction 2253: Predicted head = task_7_w_free_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 2254: Predicted head = task_7_w_free_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 2255: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 2256: Predicted head = task_9_w_sawing, True head = task_7_w_free_hard_drive
# Prediction 2257: Predicted head = task_4_k_wiping, True head = task_7_w_free_hard_drive
# Prediction 2258: Predicted head = task_8_w_hammering, True head = task_7_w_free_hard_drive
# Prediction 2259: Predicted head = task_5_k_cereals, True head = task_7_w_free_hard_drive
# Prediction 2260: Predicted head = task_7_w_free_hard_drive, True head = task_7_w_free_hard_drive
# Prediction 2261: Predicted head = task_3_k_pouring, True head = task_7_w_free_hard_drive
# Prediction 2262: Predicted head = task_9_w_sawing, True head = task_8_w_hammering
# Prediction 2263: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 2264: Predicted head = task_5_k_cereals, True head = task_8_w_hammering
# Prediction 2265: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 2266: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 2267: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 2268: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 2269: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 2270: Predicted head = task_9_w_sawing, True head = task_8_w_hammering
# Prediction 2271: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 2272: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 2273: Predicted head = task_7_w_free_hard_drive, True head = task_8_w_hammering
# Prediction 2274: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 2275: Predicted head = task_9_w_sawing, True head = task_8_w_hammering
# Prediction 2276: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 2277: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 2278: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 2279: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 2280: Predicted head = task_5_k_cereals, True head = task_8_w_hammering
# Prediction 2281: Predicted head = task_7_w_free_hard_drive, True head = task_8_w_hammering
# Prediction 2282: Predicted head = task_5_k_cereals, True head = task_8_w_hammering
# Prediction 2283: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 2284: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 2285: Predicted head = task_5_k_cereals, True head = task_8_w_hammering
# Prediction 2286: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 2287: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 2288: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 2289: Predicted head = task_7_w_free_hard_drive, True head = task_8_w_hammering
# Prediction 2290: Predicted head = task_5_k_cereals, True head = task_8_w_hammering
# Prediction 2291: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 2292: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 2293: Predicted head = task_5_k_cereals, True head = task_8_w_hammering
# Prediction 2294: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 2295: Predicted head = task_9_w_sawing, True head = task_8_w_hammering
# Prediction 2296: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 2297: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 2298: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 2299: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 2300: Predicted head = task_9_w_sawing, True head = task_8_w_hammering
# Prediction 2301: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 2302: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 2303: Predicted head = task_7_w_free_hard_drive, True head = task_8_w_hammering
# Prediction 2304: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 2305: Predicted head = task_9_w_sawing, True head = task_8_w_hammering
# Prediction 2306: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 2307: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 2308: Predicted head = task_7_w_free_hard_drive, True head = task_8_w_hammering
# Prediction 2309: Predicted head = task_5_k_cereals, True head = task_8_w_hammering
# Prediction 2310: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 2311: Predicted head = task_4_k_wiping, True head = task_8_w_hammering
# Prediction 2312: Predicted head = task_8_w_hammering, True head = task_8_w_hammering
# Prediction 2313: Predicted head = task_7_w_free_hard_drive, True head = task_8_w_hammering
# Prediction 2314: Predicted head = task_5_k_cereals, True head = task_8_w_hammering
# Prediction 2315: Predicted head = task_3_k_pouring, True head = task_8_w_hammering
# Prediction 2316: Predicted head = task_9_w_sawing, True head = task_9_w_sawing
# Prediction 2317: Predicted head = task_4_k_wiping, True head = task_9_w_sawing
# Prediction 2318: Predicted head = task_8_w_hammering, True head = task_9_w_sawing
# Prediction 2319: Predicted head = task_9_w_sawing, True head = task_9_w_sawing
# Prediction 2320: Predicted head = task_7_w_free_hard_drive, True head = task_9_w_sawing
# Prediction 2321: Predicted head = task_3_k_pouring, True head = task_9_w_sawing
# Prediction 2322: Predicted head = task_4_k_wiping, True head = task_9_w_sawing
# Prediction 2323: Predicted head = task_5_k_cereals, True head = task_9_w_sawing
# Prediction 2324: Predicted head = task_3_k_pouring, True head = task_9_w_sawing
# Prediction 2325: Predicted head = task_9_w_sawing, True head = task_9_w_sawing
# Prediction 2326: Predicted head = task_4_k_wiping, True head = task_9_w_sawing
# Prediction 2327: Predicted head = task_5_k_cereals, True head = task_9_w_sawing
# Prediction 2328: Predicted head = task_3_k_pouring, True head = task_9_w_sawing
# Prediction 2329: Predicted head = task_9_w_sawing, True head = task_9_w_sawing
# Prediction 2330: Predicted head = task_4_k_wiping, True head = task_9_w_sawing
# Prediction 2331: Predicted head = task_8_w_hammering, True head = task_9_w_sawing
# Prediction 2332: Predicted head = task_9_w_sawing, True head = task_9_w_sawing
# Prediction 2333: Predicted head = task_7_w_free_hard_drive, True head = task_9_w_sawing
# Prediction 2334: Predicted head = task_3_k_pouring, True head = task_9_w_sawing
# Prediction 2335: Predicted head = task_4_k_wiping, True head = task_9_w_sawing
# Prediction 2336: Predicted head = task_5_k_cereals, True head = task_9_w_sawing
# Prediction 2337: Predicted head = task_3_k_pouring, True head = task_9_w_sawing
# Prediction 2338: Predicted head = task_9_w_sawing, True head = task_9_w_sawing
# Prediction 2339: Predicted head = task_4_k_wiping, True head = task_9_w_sawing
# Prediction 2340: Predicted head = task_5_k_cereals, True head = task_9_w_sawing
# Prediction 2341: Predicted head = task_3_k_pouring, True head = task_9_w_sawing

# %%
import collections

collections.Counter(preds)
# Out:
# Counter({'task_4_k_wiping': 599,
#          'task_3_k_pouring': 531,
#          'task_8_w_hammering': 319,
#          'task_7_w_free_hard_drive': 278,
#          'task_5_k_cereals': 267,
#          'task_9_w_sawing': 251,
#          'task_2_k_cooking_with_bowls': 71,
#          'task_6_w_hard_drive': 25})

# %%
collections.Counter(trues)
# Out:
# Counter({'task_5_k_cereals': 415,
#          'task_8_w_hammering': 376,
#          'task_6_w_hard_drive': 316,
#          'task_7_w_free_hard_drive': 265,
#          'task_2_k_cooking_with_bowls': 220,
#          'task_1_k_cooking': 216,
#          'task_4_k_wiping': 181,
#          'task_9_w_sawing': 178,
#          'task_3_k_pouring': 174})

# %%
# parentAction_transe_word_350epochs  12%
